# %%
# !cd ../; git clone -b master https://github.com/Muennighoff/vilio.git
# !pip install -r ../vilio/py-bottom-up-attention/requirements.txt
# !pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !python ../vilio/py-bottom-up-attention/setup.py build develop
# Out:
# Collecting git+https://github.com/facebookresearch/fvcore.git (from -r ../vilio/py-bottom-up-attention/requirements.txt (line 1))
#   Cloning https://github.com/facebookresearch/fvcore.git to c:\users\user\appdata\local\temp\pip-req-build-qo0v7mo0
#   Resolved https://github.com/facebookresearch/fvcore.git to commit a491d5b9a06746f387aca2f1f9c7c7f28e20bef9
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# WARNING: Ignoring invalid distribution ~orch (C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fvcore.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-qo0v7mo0'
# ERROR: Could not find a version that satisfies the requirement torch==1.4.0 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0)
# ERROR: No matching distribution found for torch==1.4.0
# running build
# running build_ext
# building 'detectron2._C' extension
# creating build\temp.win-amd64-cpython-311\Release\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated
# creating build\temp.win-amd64-cpython-311\Release\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlign
# creating build\temp.win-amd64-cpython-311\Release\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\box_iou_rotated
# creating build\temp.win-amd64-cpython-311\Release\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\deformable
# creating build\temp.win-amd64-cpython-311\Release\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\nms_rotated
# "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.43.34808\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DWITH_CUDA -IC:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc -IC:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\include -IC:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\include\torch\csrc\api\include -IC:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\include\TH -IC:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\include\THC "-IC:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.2\include" -IC:\Users\user\PycharmProjects\pythonProject\.venv\include -IC:\Users\user\AppData\Local\Programs\Python\Python311\include -IC:\Users\user\AppData\Local\Programs\Python\Python311\Include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.43.34808\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" /EHsc /TpC:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp /Fobuild\temp.win-amd64-cpython-311\Release\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.obj /MD /wd4819 /wd4251 /wd4244 /wd4267 /wd4275 /wd4018 /wd4190 /wd4624 /wd4067 /wd4068 /EHsc -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 /std:c++17
# ROIAlignRotated_cpu.cpp
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated.h(57): warning C4996: 'at::Tensor::type': Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device().
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated.h(85): warning C4996: 'at::Tensor::type': Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device().
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(446): error C2664: 'c10::ScalarType detail::scalar_type(c10::ScalarType)': 無法將引數 1 從 'const at::DeprecatedTypeProperties' 轉換為 'c10::ScalarType'
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(446): note: 沒有可以執行此轉換的使用者定義轉換運算子或無法呼叫運算子
# C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\include\ATen/Dispatch.h(101): note: 請參閱 'detail::scalar_type' 的宣告
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(446): note: 當嘗試符合引數清單 '(const at::DeprecatedTypeProperties)' 時
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(446): warning C4996: 'at::Tensor::type': Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device().
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(497): error C2664: 'c10::ScalarType detail::scalar_type(c10::ScalarType)': 無法將引數 1 從 'const at::DeprecatedTypeProperties' 轉換為 'c10::ScalarType'
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(497): note: 沒有可以執行此轉換的使用者定義轉換運算子或無法呼叫運算子
# C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\include\ATen/Dispatch.h(101): note: 請參閱 'detail::scalar_type' 的宣告
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(497): note: 當嘗試符合引數清單 '(const at::DeprecatedTypeProperties)' 時
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio\py-bottom-up-attention\detectron2\layers\csrc\ROIAlignRotated\ROIAlignRotated_cpu.cpp(497): warning C4996: 'at::Tensor::type': Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device().
# C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\utils\cpp_extension.py:529: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\utils\cpp_extension.py:414: UserWarning: Error checking compiler version for cl: [WinError 2] 系統找不到指定的檔案。
#   warnings.warn(f'Error checking compiler version for {compiler}: {error}')
# C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages\torch\utils\cpp_extension.py:448: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.6). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.43.34808\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2

# %%
import pandas as pd
import json
import torch
data = pd.read_csv('../CLIP_prefix_caption/Model/clip_100up_only200_passlength_12_x_mcdonalds_switzerland/generate_beam_1.csv')
data
# turn it to json with image_id as id , mcdonalds_switzerland\/image_id as img, text as text
# {"id":10002,"img":"img\/10002.png","text":"one does not simply explain memes"}
jsonFile = []
for i in range(data.shape[0]):
    jsonFile.append(f'\u007b"id": "{data["image_id"][i]}", "img": "mcdonalds_switzerland_img/{data["image_id"][i]}.jpg", "text": "{data["caption"][i]}"\u007d')
with open('./data/clip_100up_only200_passlength_12_MC_generate_beam_1.jsonl', 'w', encoding='utf-8') as f:
    for item in jsonFile:
        f.write("%s\n" % item)
jsonFile
# Out:
# ['{"id": "mcdonalds_switzerland_586", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_586.jpg", "text": "tidying up for the summer? no problem at all with our new# mccafe🤩🤩🥤 ... any tips on where to find the best ones? 🤩# mcdonalds# mcdo# food# summer# bretzels# foodie# picoftheday"}',
#  '{"id": "mcdonalds_switzerland_16", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_16.jpg", "text": "i \'m sure you \'ve seen it already ... it \'s not easy being a bbq at home, but i \'m sure you \'re already warmed up by the new hamburgers 😍🍔 🍟 🥤🏃# bbqaroundtheworld# bbqaround"}',
#  '{"id": "mcdonalds_switzerland_271", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_271.jpg", "text": "craving for a cup of mcchicken soup? we have you covered with our new mcdelivery service, which automatically fills your bags as soon as you leave the mcdonald \'s® restaurant."}',
#  '{"id": "mcdonalds_switzerland_1985", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1985.jpg", "text": "a few hours before the start of the month, we ‘ re going to make some cool decorations 😎 🎁."}',
#  '{"id": "mcdonalds_switzerland_696", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_696.jpg", "text": "dear mcraclette lovers, i wish you the best day☀️☀️ and i wish you the best day☀️☀️ 🍔# mcdonalds# mcdo# gold# toblerone# tobleronexample# tobleronexamples# tobleronexamples"}',
#  '{"id": "mcdonalds_switzerland_1842", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1842.jpg", "text": "do you know switzerland as well as you think? if so, can you tell me where this mcdonald’ s restaurant is located? 📍# swissmcdelivery# food# mundlive# mcdonalds# mcdo# foodie# australian# foodie# switzerland# foodie"}',
#  '{"id": "mcdonalds_switzerland_673", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_673.jpg", "text": "i’ m not kidding when i say that we’ re enjoying our summer holidays together with our swiss friends ❤️☀️☀️ 🍔 🍟 🥤 i’ m not kidding when i say that we’ re enjoying our summer holidays together with our swiss friends �"}',
#  '{"id": "mcdonalds_switzerland_712", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_712.jpg", "text": "we know you \'ve been waiting for this for a while."}',
#  '{"id": "mcdonalds_switzerland_725", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_725.jpg", "text": "no need to wait for the new year to enjoy your favorite burgers🍔😍😍# bigmac# bigmac# new# products# neweggday# yummy# foodie# veggie# neweggsday# mcdonalds# mcdo# foodie# veggie# neweggsday#"}',
#  '{"id": "mcdonalds_switzerland_904", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_904.jpg", "text": "so yummy, so delicious 🤩 😍 who agrees? 😍# friesforlife# friesforlife# switzerland# philadelphiacheese# bretzelsporthilfe# philadelphiacheese# bretzelsporthilfe# bretzelsporthilfe#"}',
#  '{"id": "mcdonalds_switzerland_681", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_681.jpg", "text": "when we first tasted our first coca-cola\u200b latte, we always wondered how it tasted like in a coca-cola\u200b smoothie."}',
#  '{"id": "mcdonalds_switzerland_1037", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1037.jpg", "text": "summer is calling, right? 😍 thanks for the pic@ mcdonalds_switzerland for this awesome idea 🤩# summersummer# frappéal# frappéal# coffee# summer# snipes# mcdo# mcdonalds# telenovela# cappuccino# mart"}',
#  '{"id": "mcdonalds_switzerland_2039", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2039.jpg", "text": "chickpea salad for switzerland? no problem at all with our# mcdonalds# mcdo# salad# chf 9."}',
#  '{"id": "mcdonalds_switzerland_721", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_721.jpg", "text": "i \'m sure you \'ve seen it all ... right now, it \'s the moment you \'re always hungry for a slice of chicken mcnuggets® 🍔 🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_1056", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1056.jpg", "text": "i’ m so proud of@ chiarabenzalfonso and his team at the mcdonald’ s charity mcdonald’ s sydney."}',
#  '{"id": "mcdonalds_switzerland_163", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_163.jpg", "text": "when you lose a friend, it \'s usually because you \'re not as caring as you think you are 🍔 🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_481", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_481.jpg", "text": "we are there for you ... ☀️ 🍔 🍟 🥤# mcdonalds# youlivewedeliver# youlivewedeliversof# youlivewedeliversofricanamerican# youlivewedeliversofricanamericanwomen# youlivewedeliversof"}',
#  '{"id": "mcdonalds_switzerland_205", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_205.jpg", "text": "imagine that ice cream sundae with a mcflurry and a sweet tooth ❤️😍# icecream# mccafe# mcdonalds# mcdo# icecreamsunday# yummy# foodie# summer# yummytag# foodienews# switzerland# mcdo# foodie#"}',
#  '{"id": "mcdonalds_switzerland_262", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_262.jpg", "text": "morning coffee after a long day at work? 🍔 🍟 have you tried our new# mccafe breakfast menu?# mcdo# breakfast# mcdonalds# sydney# australia# coffee# breakfast# picoftheday# mcdo# telenovela# breakfast# yummy"}',
#  '{"id": "mcdonalds_switzerland_419", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_419.jpg", "text": "happy# holiday season 🍔 🍟 🥳 what do you do for a good cause 💛? 😍# holiday# mccafe# mcdonalds# mcdo# food# happy# day# yummy# foodie# foodie# trendy# trendytheday# bestoftheday"}',
#  '{"id": "mcdonalds_switzerland_173", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_173.jpg", "text": "what a delicious combo ! 🍔😍# mcdonalds# mcdo# food# delicious# combo# picoftheday# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# food"}',
#  '{"id": "mcdonalds_switzerland_654", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_654.jpg", "text": "happy friday, friday is n\'t over yet ... what \'s cooler than a chicken mcnuggets®? 😍😍# mcdonalds# mcdo# chicken# fries# friday# birthdays# picoftheday# birthdaysmakeabigdifference# happy# friday# birthdays"}',
#  '{"id": "mcdonalds_switzerland_180", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_180.jpg", "text": "do you know switzerland as well as you think? if so, can you tell me where this mcdonald \'s restaurant is located? 📍 🍟 🥤 🍔 🍟 🥤 🏃? let us know in the comments below."}',
#  '{"id": "mcdonalds_switzerland_293", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_293.jpg", "text": "i know you \'ve been waiting for this for a while."}',
#  '{"id": "mcdonalds_switzerland_1591", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1591.jpg", "text": "mccafe# mcdonalds# mcdo# gingerbread# gingerbreadday# spring# mcdonalds# spring# mcdo# gingerbread# summer# spring# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# food"}',
#  '{"id": "mcdonalds_switzerland_1882", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1882.jpg", "text": "☕️ what do you do when you don’ t want to wait for your morning coffee?# mcdonalds# mcdo# smoothie# coffee# delicious# summer# mcdonalds# yummy# foodie# snack# summer# yummytag# foodieday# switzerland# foodieday#"}',
#  '{"id": "mcdonalds_switzerland_746", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_746.jpg", "text": "it \'s time for the big tasty monstrosity to come to an end."}',
#  '{"id": "mcdonalds_switzerland_835", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_835.jpg", "text": "i know you \'ve been waiting for this for a while."}',
#  '{"id": "mcdonalds_switzerland_628", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_628.jpg", "text": "yesterday was the first day of mcdelivery."}',
#  '{"id": "mcdonalds_switzerland_859", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_859.jpg", "text": "anyway, it \'s the last game of the season."}',
#  '{"id": "mcdonalds_switzerland_448", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_448.jpg", "text": "our# bbqaroundtheworld blogger@ delivey_vlogs is sharing his best moments from his time in the# bbqaroundtheworld trip with us 🍔."}',
#  '{"id": "mcdonalds_switzerland_1883", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1883.jpg", "text": "great day to all of you@ mcdonalds_switzerland and@ stefac2002 for having a great day together with our friend@ swiss_nati_women . we look forward to seeing you next year ! happy birthday mcdonalds_switzerland !# swissnatiwomen# worldcelebration#"}',
#  '{"id": "mcdonalds_switzerland_528", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_528.jpg", "text": "the chicken mcnuggets are back."}',
#  '{"id": "mcdonalds_switzerland_655", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_655.jpg", "text": "we all have a mcdonald \'s in our lives 🍔 🍟 � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � �"}',
#  '{"id": "mcdonalds_switzerland_377", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_377.jpg", "text": "🥰 so much love for@ daim# mccafe 😵# mcdonalds# mcdo# smile# daim# fashion# fashionnews# fashionnews# fashionnews# fashionnews# fashion# swisswomen# fashionnews# fashion# swisswomen# fashion# swisswomen# fashionnews#"}',
#  '{"id": "mcdonalds_switzerland_153", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_153.jpg", "text": "we know you \'ve been waiting for this for a while ... n\'t you? tag your favorite mcdonald \'s minions in the comments and let us know which one you think is right for you !< 3< 3< 3< 3< 3< 3< 3< 3< 3< 3< 3< 3< 3"}',
#  '{"id": "mcdonalds_switzerland_2020", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2020.jpg", "text": "# repost# mcdonalds# mcdo# food# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie#"}',
#  '{"id": "mcdonalds_switzerland_774", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_774.jpg", "text": "a big mac with a side of savoury sauce 🍔 🤩 is now available in all mcdonald \'s stores in switzerland and the principality of liechtenstein."}',
#  '{"id": "mcdonalds_switzerland_265", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_265.jpg", "text": "what if i told you that everything i pay in the app is already paid in the app? that \'s all it takes."}',
#  '{"id": "mcdonalds_switzerland_178", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_178.jpg", "text": "it \'s time to fall in love with our new yummy burgers."}',
#  '{"id": "mcdonalds_switzerland_1209", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1209.jpg", "text": "only a few days left before the launch of my new mccafé.# mcdonalds# mcdo# food# launchday# mcdo# foodie# foodie# foodiexchange ❤️# launchday# mccafe# mcdonalds# mcdo# foodiexchange ❤️#"}',
#  '{"id": "mcdonalds_switzerland_222", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_222.jpg", "text": "what \'s your favorite fries game? 🤔 🍔 🍟 🥤 🏃? let us know in the comments and let us know what you think in the comments."}',
#  '{"id": "mcdonalds_switzerland_716", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_716.jpg", "text": "which one is your favorite 🍔? 😍😍# mccafe# mcdonalds# yummy# big mac# big mac# meatloaf# big mac# veggie# vegetarian# yummy# new# mcdo# yummy# neweggday# neweggday# neweggday# new"}',
#  '{"id": "mcdonalds_switzerland_165", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_165.jpg", "text": "which mcdonald \'s drink is the best? 🤩 finding the right one in the app 🍔 🍟."}',
#  '{"id": "mcdonalds_switzerland_1656", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1656.jpg", "text": "congratulations to our@ michelle_schweizers for winning silver at the youth national championships in switzerland in 2014."}',
#  '{"id": "mcdonalds_switzerland_330", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_330.jpg", "text": "i’ m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_632", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_632.jpg", "text": "imagine that feeling of excitement when you see a familiar face again 🧀? that \'s exactly what we are trying to do for you 😉 🧀# smallmomentsmakeabigdifference# mcdonalds# mcdo# friendship# smallmomentsmakeabigdifference# likescience# love#"}',
#  '{"id": "mcdonalds_switzerland_828", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_828.jpg", "text": "tag your favorite burger with the tagline: `` big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big"}',
#  '{"id": "mcdonalds_switzerland_1203", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1203.jpg", "text": "craving for fries? then we have you covered with our big tasty cheddar 🍔 🍟."}',
#  '{"id": "mcdonalds_switzerland_27", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_27.jpg", "text": "i don’ t remember what i \'m looking at right now."}',
#  '{"id": "mcdonalds_switzerland_234", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_234.jpg", "text": "you know it when you’ re tasting it: the mccafé sauce that angelenos make with their mcnuggets® and their cappuccino® . who knows the flavor? 🙌# mccafe# mcdonalds# mcdo# picoftheday# foodie# christmas#"}',
#  '{"id": "mcdonalds_switzerland_768", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_768.jpg", "text": "all i need right now is a cup of coffee and a mccafé."}',
#  '{"id": "mcdonalds_switzerland_706", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_706.jpg", "text": "when i was a kid, i always had a chicken mcnuggets® that i dipped into my mcdonald \'s menu."}',
#  '{"id": "mcdonalds_switzerland_794", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_794.jpg", "text": "i know you \'ve been arguing with your grandma for a while now, but i \'m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_2031", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2031.jpg", "text": "morning coffee after a long day at work?# mccafe# mcdonalds# coffee# morning# coffee# breakfast# yummy# foodie# trendy# mcdo# mcdonalds# yummy# foodie# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy#"}',
#  '{"id": "mcdonalds_switzerland_1948", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1948.jpg", "text": "this week we \'re celebrating a new mccafé ! it \'s a new blueberry 🥓 and it \'s a new yellow coca-cola™ glass 🥓."}',
#  '{"id": "mcdonalds_switzerland_201", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_201.jpg", "text": "do you know where this mcdonald \'s is? tell us in the comments and we \'ll see if you \'re a real og."}',
#  '{"id": "mcdonalds_switzerland_360", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_360.jpg", "text": "i want to thank you for your love ❤️🍔🍟 ❤️ so much ❤️❤️❤️❤️❤️🍩 tag your christmas spirit to the mcdonald’ s in the comments and let us know how you feel❤️�"}',
#  '{"id": "mcdonalds_switzerland_699", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_699.jpg", "text": "now that \'s what we call a big tasty combo."}',
#  '{"id": "mcdonalds_switzerland_1612", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1612.jpg", "text": "our new blue sweater is back with a ton of love 🥰."}',
#  '{"id": "mcdonalds_switzerland_1886", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1886.jpg", "text": "like this picture if you \'re lucky enough to have recently visited our# mcdonalds# mcdo# food# delicious# breakfast# trendy# switzerland# mcdo# foodie# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy# trendy#"}',
#  '{"id": "mcdonalds_switzerland_793", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_793.jpg", "text": "now that \'s the magic time of the summer: without a car, without a calendar, without any of that 🤩 🍔 🤩 🍟 🥤 🥳 🧀 🧀 🧀 🧀 🧀 🧀 🧀 🧀 �"}',
#  '{"id": "mcdonalds_switzerland_13", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_13.jpg", "text": "i know you \'ve never seen this before, but i \'m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_230", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_230.jpg", "text": "do you know switzerland as well as you think? if so, can you tell me where this mcdonald \'s restaurant is located? 📍 🍟 🥤 🏃# swissmcdelivery# restaurantsporthilfe# swissmcdelivery# mcdonalds# mcdo"}',
#  '{"id": "mcdonalds_switzerland_902", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_902.jpg", "text": "we know you \'ve been waiting for this for a while."}',
#  '{"id": "mcdonalds_switzerland_237", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_237.jpg", "text": "dear 🍔 chf fans, we are proud to announce that today’ s the 20th anniversary of the chicken mcnuggets™ 🥰."}',
#  '{"id": "mcdonalds_switzerland_203", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_203.jpg", "text": "what \'s yours? what \'s yours? 🍔 🍟 � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � � �"}',
#  '{"id": "mcdonalds_switzerland_129", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_129.jpg", "text": "it’ s time for the big bang menu."}',
#  '{"id": "mcdonalds_switzerland_480", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_480.jpg", "text": "wouldn’ t you love to eat that? 🤩 we \'re lovin\' it 😉 🍔 </s> </s> </div> </div> </div> </div> </div> </div> </div> </div> </div> </div> </div> </div"}',
#  '{"id": "mcdonalds_switzerland_623", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_623.jpg", "text": "our# mcdelivery is back 🍔 🍟 thanks to@ george."}',
#  '{"id": "mcdonalds_switzerland_457", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_457.jpg", "text": "🍔 🍟 🥤 tag your fries lover in the comments and let them know 🥰 😍# frenchfries# mcdonalds# mcdo# frieslover# happy# summer# mcdonaldsday# yummy# bigmac# frieslover# yummymakeabigdifference"}',
#  '{"id": "mcdonalds_switzerland_172", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_172.jpg", "text": "it \'s the first day of the new year and i \'m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_2026", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2026.jpg", "text": "team@ mcdonalds_switzerland and@ snipes_zuerich have come up with our new style of chicken mcnuggets® 🍔 🍟."}',
#  '{"id": "mcdonalds_switzerland_285", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_285.jpg", "text": "now that \'s what \'s going on with our happy birthday kids 😉 💛# happybirthdays# picoftheday# yummypicoftheday# christmas# picoftheday# yummypicoftheday# christmas# christmas# picoftheday#"}',
#  '{"id": "mcdonalds_switzerland_411", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_411.jpg", "text": "sun’ s out and we’ re lovin\' it: our new# aprilburger® ice tea from swiss-exclusive mcdonald’ s is now available in all our restaurants."}',
#  '{"id": "mcdonalds_switzerland_858", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_858.jpg", "text": "what a great way to celebrate the 1st of august 🎉."}',
#  '{"id": "mcdonalds_switzerland_596", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_596.jpg", "text": "hopp schmudo 🍔 🍟 🥤 🍔 🍟 🥤 🍔 🍟 🥤 🍔 🍟 🥤 🍔 🍟 🥤 🍔 🍟 🥤 🍔 🍟 �"}',
#  '{"id": "mcdonalds_switzerland_637", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_637.jpg", "text": "we know you \'ve been waiting for this for a long time."}',
#  '{"id": "mcdonalds_switzerland_60", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_60.jpg", "text": "⚠️ contest ⚠️ are you ready to win a steakhouse mug? thanks to@ swiss_giants_switzerland for sharing this awesome video with us 📷🏼# hungryforlove# mcdonalds# mcdo# cheese# steakhouse# swissmcdelivery#"}',
#  '{"id": "mcdonalds_switzerland_714", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_714.jpg", "text": "have you tried it already? i \'m lovin\' it 🍔 🍟 🥤 thank you@ xavier_alfonso for sharing this video with us."}',
#  '{"id": "mcdonalds_switzerland_52", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_52.jpg", "text": "we are celebrating the 1st of august: our swiss national mcraclette is now exclusively available in our hamburger shop.# mcraclette# swissnationalmcraclette# mcdonalds# mcdo# food# switzerland# swissnews# swissnews."}',
#  '{"id": "mcdonalds_switzerland_232", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_232.jpg", "text": "get ready for the sunshine 😉🥵 are you n\'t dreaming? 😉🥵 are you n\'t dreaming? 😉🌶️ get ready for the sunshine 😉🥵 are you n\'t dreaming? 🌶️ get ready for the sun 😉🥵 are you n\'t dreaming? �"}',
#  '{"id": "mcdonalds_switzerland_31", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_31.jpg", "text": "a few days ago, i met up with my friend at the mcdonald \'s."}',
#  '{"id": "mcdonalds_switzerland_662", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_662.jpg", "text": "when will you order the spicy mcchicken mcnuggets®? if so, can you tell me where this is located? link in bio."}',
#  '{"id": "mcdonalds_switzerland_1934", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1934.jpg", "text": "best burger in the world? 🍔 🤩 finding the right one for you? from now on, we \'ll be able to serve it to you right here in our app 🤩."}',
#  '{"id": "mcdonalds_switzerland_1219", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1219.jpg", "text": "small things make a big difference.# mcdonalds# mcdo# hamburger# fries# picoftheday# switzerland# swissmcdelivery# swissmcdelivery# freedonut# freedonutmerch# freedonutmerch."}',
#  '{"id": "mcdonalds_switzerland_273", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_273.jpg", "text": "and there \'s a big mac and fries with every meal."}',
#  '{"id": "mcdonalds_switzerland_50", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_50.jpg", "text": "i know you \'ve been waiting for this for a while now."}',
#  '{"id": "mcdonalds_switzerland_1197", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1197.jpg", "text": "want to share fries with your friends? then we’ re sure you will enjoy this tasty.# friesforlife# love# friesforlife# mcdonalds# mcdo# picoftheday# happy# friesday# yummy# yummytag# foodie# funny# funnyday# video# video#"}',
#  '{"id": "mcdonalds_switzerland_715", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_715.jpg", "text": "craving for our new refreshing caffè latte? here it is: our new# barista# gingerbread sundae# gingerbread margarita# gingerbread latte# gingerbread margaritaville# gingerbread margaritaville# gingerbread margaritaville# gingerbread margar"}',
#  '{"id": "mcdonalds_switzerland_2025", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2025.jpg", "text": "and what \'s your favorite moment of your life? let us know in the comments section below."}',
#  '{"id": "mcdonalds_switzerland_2001", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2001.jpg", "text": "☀️ if you love our fries as much as we do, we can’ t wait to serve you our new# goldenfries🍔 🍟 😍# fries# yummy# foodie# yummylove# mcdonalds# mcdo# foodiereligion# christmas# yummy"}',
#  '{"id": "mcdonalds_switzerland_2006", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2006.jpg", "text": "our big bang menu is now available for only 1.-day delivery in the mcdonald’ s app 🍔."}',
#  '{"id": "mcdonalds_switzerland_117", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_117.jpg", "text": "lmao, it \'s time for the chicken mcnuggets® 😉 🍔 who \'s lovin\' them? 🤩@ chiarabenzalfonso, can you tell me where this mcdonald \'s restaurant is located?# lgbt# mcdonalds# mcdo# food#"}',
#  '{"id": "mcdonalds_switzerland_81", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_81.jpg", "text": "the big bang menu is still available in the mcdonald \'s app as of today."}',
#  '{"id": "mcdonalds_switzerland_1904", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1904.jpg", "text": "our# re-opened mcdonald \'s restaurant# yummy is back 🥳# mcdo# food# re-opened# australian# mcdonalds# mcdo# foodie# yummy# foodie# yummy# foodie# new# mcdonalds# mcdonaldsmerch# food"}',
#  '{"id": "mcdonalds_switzerland_169", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_169.jpg", "text": "happy meal, happy kids, happy friends ... that \'s all it takes for me to be a good person again."}',
#  '{"id": "mcdonalds_switzerland_6", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_6.jpg", "text": "i \'m sure you already know what i \'m talking about ... i \'m sure you already know what i \'m talking about ... i \'m sure you already know what i \'m talking about ... i \'m sure you already know what i \'m talking about ... i \'m sure you already know what i \'m"}',
#  '{"id": "mcdonalds_switzerland_242", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_242.jpg", "text": "give us your combination in the comments and we’ ll come up with the next burger heaven winner ! 😍& thank you@ lichtenstein for sharing this awesome video with us& the team at the carnival !& thank you@ switzerland_nati_women for sharing this awesome video with us& the team at"}',
#  '{"id": "mcdonalds_switzerland_220", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_220.jpg", "text": "do you know switzerland as well as you think? if so, can you tell me where this mcdonald \'s restaurant is located? 📍 🍔 🍟 🥤 🏃# mcdonalds# mcdogever# swissmcdelivery# amazon# imlovinit#"}',
#  '{"id": "mcdonalds_switzerland_2032", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2032.jpg", "text": "# mcdonalds# mcdo# yummy# food# yummy# yummy# yummy# yummy# yummy# mcdonalds# mcdo# restaurants# yummy# foodstagram# imlovinit# mcdonalds# yummy# foodie# foodie# foodie# foodie#"}',
#  '{"id": "mcdonalds_switzerland_676", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_676.jpg", "text": "the big mac 🍔 is back 🍟 🍔 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 �"}',
#  '{"id": "mcdonalds_switzerland_2014", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2014.jpg", "text": "# repost# yummy# cheeseburger# yummy# yummy# yummy# yummy# x-mas# mcdonalds# mcdo# yummy# christmas# yummy# yummy# christmas# yummy# christmas# yummy# christmas# yummy# christmas#"}',
#  '{"id": "mcdonalds_switzerland_248", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_248.jpg", "text": "it’ s not easy finding the right mcdonald’ s products at mcdonald’ s, but we’ re here to help."}',
#  '{"id": "mcdonalds_switzerland_7", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_7.jpg", "text": "craving for the big tasty combo? now is the perfect time to try our new mcchicken burgers🍔 🍟."}',
#  '{"id": "mcdonalds_switzerland_2035", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2035.jpg", "text": "the big mac is back 🍔🍟 and the sauce is even better:)# bigmac# spicy# mcdo# mcdonalds# bretzels# bbq# foodie# foodie# foodiexchange# foodiezine# foodiexswitzerland# foodiezine"}',
#  '{"id": "mcdonalds_switzerland_1168", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1168.jpg", "text": "we \'re lovin\' you 😉@ mcdonalds_switzerland and@ bernsteiner_switzerland have teamed up to write a bio for@ bernsteiner_switzerland."}',
#  '{"id": "mcdonalds_switzerland_668", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_668.jpg", "text": "our# 1st big mac is now available in a double cheeseburger, with veggie burgers or as a double cheeseburger only."}',
#  '{"id": "mcdonalds_switzerland_617", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_617.jpg", "text": "today is the 10th anniversary of our# mccafé."}',
#  '{"id": "mcdonalds_switzerland_868", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_868.jpg", "text": "do you also dream of bacon? if so, can you tell me which one is real? 👀 tell us in the comments below."}',
#  '{"id": "mcdonalds_switzerland_45", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_45.jpg", "text": "looks like@ mcdonalds_switzerland and@ cozydakidzombies are celebrating the 7th of july with a big mac.# mcdonalds# burger# burgerday# international# foodie# burgerfan# mcdo# burgerlookslike# dreamhack# dreamhackday# lucky# lucky"}',
#  '{"id": "mcdonalds_switzerland_118", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_118.jpg", "text": "did you know that every time you eat a big mac you get a hallucination? that \'s how it works in the real world."}',
#  '{"id": "mcdonalds_switzerland_1215", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1215.jpg", "text": "big bang breakfast menu for you: our new# big bang breakfast menu for you: our new# mcdonalds# mcdo# burgers# breakfast# breakfast# burgerslover# love# foodie# switzerland# swissmcdelivery# bretzels# picoftheday# bestoftheday"}',
#  '{"id": "mcdonalds_switzerland_735", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_735.jpg", "text": "today we \'re proud to announce that our fabrizi zürich chicken is now available as a signed bonus with every participating mcdonald’ s restaurant in switzerland and the principality of liechtenstein."}',
#  '{"id": "mcdonalds_switzerland_54", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_54.jpg", "text": "i don’ t think so ... it \'s time for a big breakfast ... what’ s in your bag for you? 🍔 hap 👍# bigtastyday# mcdonalds# mcdo# breakfast# foodie# mundanity# mundypost# mundypost# foodie# mund"}',
#  '{"id": "mcdonalds_switzerland_691", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_691.jpg", "text": "have you tried our new swiss sweet tooth ice cream sundae? we’ ll surprise you with one of our new sweet tooth ice cream sundae 🥰 🍔 🤤# icecreamsundae# yummy# christmas# icecreamsunday# switzerland# mundypost# mund"}',
#  '{"id": "mcdonalds_switzerland_181", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_181.jpg", "text": "pornography is not for everyone, but for me, it’ s the medium that makes me feel good 🤩 🍔 🤩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 �"}',
#  '{"id": "mcdonalds_switzerland_69", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_69.jpg", "text": "i don’ t remember what i \'m looking at right now."}',
#  '{"id": "mcdonalds_switzerland_864", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_864.jpg", "text": "if you love the bacchanal as much as i do, please consider donating a little bit of your money to the mcdonald \'s charities in bio@ mcdonalds# bacchanal# mcdonaldsswitzerland# fas."}',
#  '{"id": "mcdonalds_switzerland_672", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_672.jpg", "text": "i’ m so sorry for the loss of our hamburgers but we’ re so proud of you’ s ! we’ re lovin\' it 😉 🥶🍔# wearelovinit# youlivelosingit# youlivelosingit# mcdonalds# mcdo"}',
#  '{"id": "mcdonalds_switzerland_683", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_683.jpg", "text": "it \'s official: we \'ve got the mcraclette for you."}',
#  '{"id": "mcdonalds_switzerland_1", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1.jpg", "text": "don’ t sleep at night."}',
#  '{"id": "mcdonalds_switzerland_236", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_236.jpg", "text": "there \'s a reason we \'re so proud of you."}',
#  '{"id": "mcdonalds_switzerland_122", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_122.jpg", "text": "guess who uses order& pay in the mcdonald’ s app? if so, can you tell me where it is? link in bio."}',
#  '{"id": "mcdonalds_switzerland_256", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_256.jpg", "text": "we \'re there for you: every time you use the word \'ve \' in front of me, i \'m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_769", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_769.jpg", "text": "in case you were wondering, in case you haven’ t ... chicken mcnuggets® are available in all the mcdonald’ s restaurants in switzerland and in the principality of liechtenstein."}',
#  '{"id": "mcdonalds_switzerland_364", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_364.jpg", "text": "do you know switzerland as well as you think? if so, can you tell me where this mcdonald \'s shop is located? if so, can you tell me where this mcdonald \'s restaurant is located? 📍\u200d🏼# swissmcdelivery# mcdonalds# mcdo"}',
#  '{"id": "mcdonalds_switzerland_59", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_59.jpg", "text": "good news: we’ re back with a new mccafé ☀️🤩 for all our swiss fans out there 😍# baconday# mcdonalds# mcdo# bretzels# bretzelsbanana# bretzelsswitzerland# bretzelswe"}',
#  '{"id": "mcdonalds_switzerland_80", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_80.jpg", "text": "i \'m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_22", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_22.jpg", "text": "chick-fil-a day is n\'t over yet: come and try our new spicy mcchicken mcnuggets® for only 1.- chf."}',
#  '{"id": "mcdonalds_switzerland_90", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_90.jpg", "text": "if you \'re a american, you \'re going to mcdonald \'s right now 🇨🇭."}',
#  '{"id": "mcdonalds_switzerland_677", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_677.jpg", "text": "our new# mccafe 🌶️ is now available in three different shades 🌶️: clear, grey, and black 🍔 🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_251", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_251.jpg", "text": "when did you first discover the big tasty burgers that are now available in switzerland?# bigtastyburger# swissmcdelivery# burgerday# swissmcdeliveryday# swissmcdeliveryday# mcdonalds# mcdo# burgerday# swissmcdeliveryday"}',
#  '{"id": "mcdonalds_switzerland_2016", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_2016.jpg", "text": "big mac? big mac? big mac lover? then you should try our new big mac products in the next couple of days."}',
#  '{"id": "mcdonalds_switzerland_1871", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1871.jpg", "text": "coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee, coffee,"}',
#  '{"id": "mcdonalds_switzerland_447", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_447.jpg", "text": "shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake it, shake"}',
#  '{"id": "mcdonalds_switzerland_1138", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1138.jpg", "text": "craving for fries? then we’ re here for you."}',
#  '{"id": "mcdonalds_switzerland_332", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_332.jpg", "text": "ver 2nd of march, as of today, all you need is love and a mcdonald \'s menu 😎# theendlessdaysmakeabigdifference# freedonutbread# freedonutbreadsundaysmakeabigdifference# freedonutbreadsundayslove# freedonutbreadsundayslove#"}',
#  '{"id": "mcdonalds_switzerland_19", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_19.jpg", "text": "a new way to celebrate the yummy way of life: our# bbqaroundtheworld veggie breakfast.# fabiofuturedad# bbqaroundtheworld# bbqaroundtheworldwedeliver# bbqaroundtheworldwedeliver# bbqaroundtheworldwedeliver"}',
#  '{"id": "mcdonalds_switzerland_227", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_227.jpg", "text": "i’ m so proud of@ macaron_troispattes for tagging me in this 🍔 🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_732", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_732.jpg", "text": "thank you for the fries 😄🍟 😍# frenchfries# mcdonalds# frieslover# happy# summer# mcdo# friendship# friendship# friendshipswitzerland# picoftheday# happy# delivey# mcdonalds# mcdo# foodie# friendship# picoft"}',
#  '{"id": "mcdonalds_switzerland_1132", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1132.jpg", "text": "we \'re celebrating the first day of the new year 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 �"}',
#  '{"id": "mcdonalds_switzerland_693", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_693.jpg", "text": "oohooo 🍔 🍟 i know you \'ve been waiting for this for a while ... 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩"}',
#  '{"id": "mcdonalds_switzerland_1196", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1196.jpg", "text": "angry fans of chicken big mac should try our new spicy chicken big mac 🍔 🍟 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 �"}',
#  '{"id": "mcdonalds_switzerland_1962", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_1962.jpg", "text": "i \'m lovin\' it, we \'re lovin\' it !# mcdonalds# mcdo# steak# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer# summer"}',
#  '{"id": "mcdonalds_switzerland_168", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_168.jpg", "text": "if you \'ve never been to the moon before, hang in there \'ll be no problem at all ... i \'m sure you already know what \'s in store for you 🙌🏼# moonadventure# youlivewedeliver# youlivewedeliverstop# youlivewedeliver2020#"}',
#  '{"id": "mcdonalds_switzerland_682", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_682.jpg", "text": "but there’ s a problem ... 🍔 🍟 🥤 don’ t forget to subscribe to my newsletter so you never miss an episode 🍟 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 🍩 ..."}',
#  '{"id": "mcdonalds_switzerland_730", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_730.jpg", "text": "yesterday was the thirteenth day of the ronald mcdonald holiday shopping season."}',
#  '{"id": "mcdonalds_switzerland_645", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_645.jpg", "text": "chicken or veggie? if so, can you tell me which is which?# mcdonalds# mcdo# food# chicken# veggie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie# foodie"}',
#  '{"id": "mcdonalds_switzerland_625", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_625.jpg", "text": "when you \'re not looking, you \'ll always be looking at the mcdonald \'s menu 🤩 🍔 🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_73", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_73.jpg", "text": "the first bite of our new# mccafe 🍔 🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_713", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_713.jpg", "text": "it’ s time to admit it: i love big mac hamburgers so much that they even eat their fingers out of them 🤓😍😍# bigmacbabes# bigmacbabeslove# mcfamilyswitzerland# mcdonalds# delivey# burgeroftheday#"}',
#  '{"id": "mcdonalds_switzerland_748", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_748.jpg", "text": "⚠️ a few weeks ago, i launched my first ever mac-themed dessert: the gold mac 🍔.(⚠️ link in bio)# goldmcdelivery# delivey# food# summer# telenovela# mcdonalds# mcdo# telenovela2020#"}',
#  '{"id": "mcdonalds_switzerland_737", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_737.jpg", "text": "i love you for all the reasons in the world."}',
#  '{"id": "mcdonalds_switzerland_395", "img": "mcdonalds_switzerland_img/mcdonalds_switzerland_395.jpg", "text": "summer is n\'t over yet ☀️ but i \'m craving for a caffè latte 🤩 🍔 😍# mcdonalds# mcdo# bretzels# toblerone# tobleronextra # tobleronextraflava# tobleronexchange#"}']

# %%
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# PIL.Image.LINEAR no longer exists Use BILINEAR or Resampling.BILINEAR instead.
# change site-packages/detectron2 to detectron2_dumb

# %%
# %%writefile ../vilio/py-bottom-up-attention/detectron2/config/defaults.py
# Copyright (c) Facebook, Inc. and its affiliates. All Rights Reserved
from .config import CfgNode as CN

# -----------------------------------------------------------------------------
# Convention about Training / Test specific parameters
# -----------------------------------------------------------------------------
# Whenever an argument can be either used for training or for testing, the
# corresponding name will be post-fixed by a _TRAIN for a training parameter,
# or _TEST for a test-specific parameter.
# For example, the number of images during training will be
# IMAGES_PER_BATCH_TRAIN, while the number of images for testing will be
# IMAGES_PER_BATCH_TEST

# -----------------------------------------------------------------------------
# Config definition
# -----------------------------------------------------------------------------

_C = CN()

_C.VERSION = 2

_C.MODEL = CN()
_C.MODEL.LOAD_PROPOSALS = False
_C.MODEL.MASK_ON = False
_C.MODEL.KEYPOINT_ON = False
_C.MODEL.DEVICE = "cpu"
_C.MODEL.META_ARCHITECTURE = "GeneralizedRCNN"

# Caffe Options
_C.MODEL.CAFFE_MAXPOOL = False

# Path (possibly with schema like catalog:// or detectron2://) to a checkpoint file
# to be loaded to the model. You can find available models in the model zoo.
_C.MODEL.WEIGHTS = ""

# Values to be used for image normalization (BGR order).
# To train on images of different number of channels, just set different mean & std.
# Default values are the mean pixel value from ImageNet: [103.53, 116.28, 123.675]
_C.MODEL.PIXEL_MEAN = [103.530, 116.280, 123.675]
# When using pre-trained models in Detectron1 or any MSRA models,
# std has been absorbed into its conv1 weights, so the std needs to be set 1.
# Otherwise, you can use [57.375, 57.120, 58.395] (ImageNet std)
_C.MODEL.PIXEL_STD = [1.0, 1.0, 1.0]


# -----------------------------------------------------------------------------
# INPUT
# -----------------------------------------------------------------------------
_C.INPUT = CN()
# Size of the smallest side of the image during training
_C.INPUT.MIN_SIZE_TRAIN = (800,)
# Sample size of smallest side by choice or random selection from range give by
# INPUT.MIN_SIZE_TRAIN
_C.INPUT.MIN_SIZE_TRAIN_SAMPLING = "choice"
# Maximum size of the side of the image during training
_C.INPUT.MAX_SIZE_TRAIN = 1333
# Size of the smallest side of the image during testing. Set to zero to disable resize in testing.
_C.INPUT.MIN_SIZE_TEST = 800
# Maximum size of the side of the image during testing
_C.INPUT.MAX_SIZE_TEST = 1333

# `True` if cropping is used for data augmentation during training
_C.INPUT.CROP = CN({"ENABLED": False})
# Cropping type:
# - "relative" crop (H * CROP.SIZE[0], W * CROP.SIZE[1]) part of an input of size (H, W)
# - "relative_range" uniformly sample relative crop size from between [CROP.SIZE[0], [CROP.SIZE[1]].
#   and  [1, 1] and use it as in "relative" scenario.
# - "absolute" crop part of an input with absolute size: (CROP.SIZE[0], CROP.SIZE[1]).
_C.INPUT.CROP.TYPE = "relative_range"
# Size of crop in range (0, 1] if CROP.TYPE is "relative" or "relative_range" and in number of
# pixels if CROP.TYPE is "absolute"
_C.INPUT.CROP.SIZE = [0.9, 0.9]


# Whether the model needs RGB, YUV, HSV etc.
# Should be one of the modes defined here, as we use PIL to read the image:
# https://pillow.readthedocs.io/en/stable/handbook/concepts.html#concept-modes
# with BGR being the one exception. One can set image format to BGR, we will
# internally use RGB for conversion and flip the channels over
_C.INPUT.FORMAT = "BGR"
_C.INPUT.MASK_FORMAT = "polygon"  # alternative: "bitmask"


# -----------------------------------------------------------------------------
# Dataset
# -----------------------------------------------------------------------------
_C.DATASETS = CN()
# List of the dataset names for training. Must be registered in DatasetCatalog
_C.DATASETS.TRAIN = ()
# List of the pre-computed proposal files for training, which must be consistent
# with datasets listed in DATASETS.TRAIN.
_C.DATASETS.PROPOSAL_FILES_TRAIN = ()
# Number of top scoring precomputed proposals to keep for training
_C.DATASETS.PRECOMPUTED_PROPOSAL_TOPK_TRAIN = 2000
# List of the dataset names for testing. Must be registered in DatasetCatalog
_C.DATASETS.TEST = ()
# List of the pre-computed proposal files for test, which must be consistent
# with datasets listed in DATASETS.TEST.
_C.DATASETS.PROPOSAL_FILES_TEST = ()
# Number of top scoring precomputed proposals to keep for test
_C.DATASETS.PRECOMPUTED_PROPOSAL_TOPK_TEST = 1000

# -----------------------------------------------------------------------------
# DataLoader
# -----------------------------------------------------------------------------
_C.DATALOADER = CN()
# Number of data loading threads
_C.DATALOADER.NUM_WORKERS = 4
# If True, each batch should contain only images for which the aspect ratio
# is compatible. This groups portrait images together, and landscape images
# are not batched with portrait images.
_C.DATALOADER.ASPECT_RATIO_GROUPING = True
# Options: TrainingSampler, RepeatFactorTrainingSampler
_C.DATALOADER.SAMPLER_TRAIN = "TrainingSampler"
# Repeat threshold for RepeatFactorTrainingSampler
_C.DATALOADER.REPEAT_THRESHOLD = 0.0
# if True, the dataloader will filter out images that have no associated
# annotations at train time.
_C.DATALOADER.FILTER_EMPTY_ANNOTATIONS = True

# ---------------------------------------------------------------------------- #
# Backbone options
# ---------------------------------------------------------------------------- #
_C.MODEL.BACKBONE = CN()

_C.MODEL.BACKBONE.NAME = "build_resnet_backbone"
# Add StopGrad at a specified stage so the bottom layers are frozen
_C.MODEL.BACKBONE.FREEZE_AT = 2


# ---------------------------------------------------------------------------- #
# FPN options
# ---------------------------------------------------------------------------- #
_C.MODEL.FPN = CN()
# Names of the input feature maps to be used by FPN
# They must have contiguous power of 2 strides
# e.g., ["res2", "res3", "res4", "res5"]
_C.MODEL.FPN.IN_FEATURES = []
_C.MODEL.FPN.OUT_CHANNELS = 256

# Options: "" (no norm), "GN"
_C.MODEL.FPN.NORM = ""

# Types for fusing the FPN top-down and lateral features. Can be either "sum" or "avg"
_C.MODEL.FPN.FUSE_TYPE = "sum"


# ---------------------------------------------------------------------------- #
# Proposal generator options
# ---------------------------------------------------------------------------- #
_C.MODEL.PROPOSAL_GENERATOR = CN()
# Current proposal generators include "RPN", "RRPN" and "PrecomputedProposals"
_C.MODEL.PROPOSAL_GENERATOR.NAME = "RPN"
_C.MODEL.PROPOSAL_GENERATOR.HID_CHANNELS = -1
# Proposal height and width both need to be greater than MIN_SIZE
# (a the scale used during training or inference)
_C.MODEL.PROPOSAL_GENERATOR.MIN_SIZE = 0


# ---------------------------------------------------------------------------- #
# Anchor generator options
# ---------------------------------------------------------------------------- #
_C.MODEL.ANCHOR_GENERATOR = CN()
# The generator can be any name in the ANCHOR_GENERATOR registry
_C.MODEL.ANCHOR_GENERATOR.NAME = "DefaultAnchorGenerator"
# anchor sizes given in absolute pixels w.r.t. the scaled network input.
# Format: list of lists of sizes. SIZES[i] specifies the list of sizes
# to use for IN_FEATURES[i]; len(SIZES) == len(IN_FEATURES) must be true,
# or len(SIZES) == 1 is true and size list SIZES[0] is used for all
# IN_FEATURES.
_C.MODEL.ANCHOR_GENERATOR.SIZES = [[32, 64, 128, 256, 512]]
# Anchor aspect ratios.
# Format is list of lists of sizes. ASPECT_RATIOS[i] specifies the list of aspect ratios
# to use for IN_FEATURES[i]; len(ASPECT_RATIOS) == len(IN_FEATURES) must be true,
# or len(ASPECT_RATIOS) == 1 is true and aspect ratio list ASPECT_RATIOS[0] is used
# for all IN_FEATURES.
_C.MODEL.ANCHOR_GENERATOR.ASPECT_RATIOS = [[0.5, 1.0, 2.0]]
# Anchor angles.
# list[float], the angle in degrees, for each input feature map.
# ANGLES[i] specifies the list of angles for IN_FEATURES[i].
_C.MODEL.ANCHOR_GENERATOR.ANGLES = [[-90, 0, 90]]
# Relative offset between the center of the first anchor and the top-left corner of the image
# Units: fraction of feature map stride (e.g., 0.5 means half stride)
# Allowed values are floats in [0, 1) range inclusive.
# Recommended value is 0.5, although it is not expected to affect model accuracy.
_C.MODEL.ANCHOR_GENERATOR.OFFSET = 0.0


# ---------------------------------------------------------------------------- #
# RPN options
# ---------------------------------------------------------------------------- #
_C.MODEL.RPN = CN()
_C.MODEL.RPN.HEAD_NAME = "StandardRPNHead"  # used by RPN_HEAD_REGISTRY

# Names of the input feature maps to be used by RPN
# e.g., ["p2", "p3", "p4", "p5", "p6"] for FPN
_C.MODEL.RPN.IN_FEATURES = ["res4"]
# Remove RPN anchors that go outside the image by BOUNDARY_THRESH pixels
# Set to -1 or a large value, e.g. 100000, to disable pruning anchors
_C.MODEL.RPN.BOUNDARY_THRESH = -1
# IOU overlap ratios [BG_IOU_THRESHOLD, FG_IOU_THRESHOLD]
# Minimum overlap required between an anchor and ground-truth box for the
# (anchor, gt box) pair to be a positive example (IoU >= FG_IOU_THRESHOLD
# ==> positive RPN example: 1)
# Maximum overlap allowed between an anchor and ground-truth box for the
# (anchor, gt box) pair to be a negative examples (IoU < BG_IOU_THRESHOLD
# ==> negative RPN example: 0)
# Anchors with overlap in between (BG_IOU_THRESHOLD <= IoU < FG_IOU_THRESHOLD)
# are ignored (-1)
_C.MODEL.RPN.IOU_THRESHOLDS = [0.3, 0.7]
_C.MODEL.RPN.IOU_LABELS = [0, -1, 1]
# Total number of RPN examples per image
_C.MODEL.RPN.BATCH_SIZE_PER_IMAGE = 256
# Target fraction of foreground (positive) examples per RPN minibatch
_C.MODEL.RPN.POSITIVE_FRACTION = 0.5
# Weights on (dx, dy, dw, dh) for normalizing RPN anchor regression targets
_C.MODEL.RPN.BBOX_REG_WEIGHTS = (1.0, 1.0, 1.0, 1.0)
# The transition point from L1 to L2 loss. Set to 0.0 to make the loss simply L1.
_C.MODEL.RPN.SMOOTH_L1_BETA = 0.0
_C.MODEL.RPN.LOSS_WEIGHT = 1.0
# Number of top scoring RPN proposals to keep before applying NMS
# When FPN is used, this is *per FPN level* (not total)
_C.MODEL.RPN.PRE_NMS_TOPK_TRAIN = 12000
_C.MODEL.RPN.PRE_NMS_TOPK_TEST = 6000
# Number of top scoring RPN proposals to keep after applying NMS
# When FPN is used, this limit is applied per level and then again to the union
# of proposals from all levels
# NOTE: When FPN is used, the meaning of this config is different from Detectron1.
# It means per-batch topk in Detectron1, but per-image topk here.
# See "modeling/rpn/rpn_outputs.py" for details.
_C.MODEL.RPN.POST_NMS_TOPK_TRAIN = 2000
_C.MODEL.RPN.POST_NMS_TOPK_TEST = 1000
# NMS threshold used on RPN proposals
_C.MODEL.RPN.NMS_THRESH = 0.7

# ---------------------------------------------------------------------------- #
# ROI HEADS options
# ---------------------------------------------------------------------------- #
_C.MODEL.ROI_HEADS = CN()
_C.MODEL.ROI_HEADS.NAME = "Res5ROIHeads"
# Number of foreground classes
_C.MODEL.ROI_HEADS.NUM_CLASSES = 80
# Names of the input feature maps to be used by ROI heads
# Currently all heads (box, mask, ...) use the same input feature map list
# e.g., ["p2", "p3", "p4", "p5"] is commonly used for FPN
_C.MODEL.ROI_HEADS.IN_FEATURES = ["res4"]
# IOU overlap ratios [IOU_THRESHOLD]
# Overlap threshold for an RoI to be considered background (if < IOU_THRESHOLD)
# Overlap threshold for an RoI to be considered foreground (if >= IOU_THRESHOLD)
_C.MODEL.ROI_HEADS.IOU_THRESHOLDS = [0.5]
_C.MODEL.ROI_HEADS.IOU_LABELS = [0, 1]
# RoI minibatch size *per image* (number of regions of interest [ROIs])
# Total number of RoIs per training minibatch =
#   ROI_HEADS.BATCH_SIZE_PER_IMAGE * SOLVER.IMS_PER_BATCH
# E.g., a common configuration is: 512 * 16 = 8192
_C.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
# Target fraction of RoI minibatch that is labeled foreground (i.e. class > 0)
_C.MODEL.ROI_HEADS.POSITIVE_FRACTION = 0.25

# Only used on test mode

# Minimum score threshold (assuming scores in a [0, 1] range); a value chosen to
# balance obtaining high recall with not having too many low precision
# detections that will slow down inference post processing steps (like NMS)
# A default threshold of 0.0 increases AP by ~0.2-0.3 but significantly slows down
# inference.
_C.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.05
# Overlap threshold used for non-maximum suppression (suppress boxes with
# IoU >= this threshold)
_C.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5
# If True, augment proposals with ground-truth boxes before sampling proposals to
# train ROI heads.
_C.MODEL.ROI_HEADS.PROPOSAL_APPEND_GT = True


# ---------------------------------------------------------------------------- #
# Box Head
# ---------------------------------------------------------------------------- #
_C.MODEL.ROI_BOX_HEAD = CN()
# C4 don't use head name option
# Options for non-C4 models: FastRCNNConvFCHead,
_C.MODEL.ROI_BOX_HEAD.NAME = ""
# Default weights on (dx, dy, dw, dh) for normalizing bbox regression targets
# These are empirically chosen to approximately lead to unit variance targets
_C.MODEL.ROI_BOX_HEAD.BBOX_REG_WEIGHTS = (10.0, 10.0, 5.0, 5.0)
# The transition point from L1 to L2 loss. Set to 0.0 to make the loss simply L1.
_C.MODEL.ROI_BOX_HEAD.SMOOTH_L1_BETA = 0.0
_C.MODEL.ROI_BOX_HEAD.POOLER_RESOLUTION = 14
_C.MODEL.ROI_BOX_HEAD.POOLER_SAMPLING_RATIO = 0
# Type of pooling operation applied to the incoming feature map for each RoI
_C.MODEL.ROI_BOX_HEAD.POOLER_TYPE = "ROIAlignV2"
_C.MODEL.ROI_BOX_HEAD.RES5HALVE = True
_C.MODEL.ROI_BOX_HEAD.ATTR = False
_C.MODEL.ROI_BOX_HEAD.NUM_ATTRS = -1

_C.MODEL.ROI_BOX_HEAD.NUM_FC = 0
# Hidden layer dimension for FC layers in the RoI box head
_C.MODEL.ROI_BOX_HEAD.FC_DIM = 1024
_C.MODEL.ROI_BOX_HEAD.NUM_CONV = 0
# Channel dimension for Conv layers in the RoI box head
_C.MODEL.ROI_BOX_HEAD.CONV_DIM = 256
# Normalization method for the convolution layers.
# Options: "" (no norm), "GN", "SyncBN".
_C.MODEL.ROI_BOX_HEAD.NORM = ""
# Whether to use class agnostic for bbox regression
_C.MODEL.ROI_BOX_HEAD.CLS_AGNOSTIC_BBOX_REG = False

# ---------------------------------------------------------------------------- #
# Cascaded Box Head
# ---------------------------------------------------------------------------- #
_C.MODEL.ROI_BOX_CASCADE_HEAD = CN()
# The number of cascade stages is implicitly defined by the length of the following two configs.
_C.MODEL.ROI_BOX_CASCADE_HEAD.BBOX_REG_WEIGHTS = (
    (10.0, 10.0, 5.0, 5.0),
    (20.0, 20.0, 10.0, 10.0),
    (30.0, 30.0, 15.0, 15.0),
)
_C.MODEL.ROI_BOX_CASCADE_HEAD.IOUS = (0.5, 0.6, 0.7)


# ---------------------------------------------------------------------------- #
# Mask Head
# ---------------------------------------------------------------------------- #
_C.MODEL.ROI_MASK_HEAD = CN()
_C.MODEL.ROI_MASK_HEAD.NAME = "MaskRCNNConvUpsampleHead"
_C.MODEL.ROI_MASK_HEAD.POOLER_RESOLUTION = 14
_C.MODEL.ROI_MASK_HEAD.POOLER_SAMPLING_RATIO = 0
_C.MODEL.ROI_MASK_HEAD.NUM_CONV = 0  # The number of convs in the mask head
_C.MODEL.ROI_MASK_HEAD.CONV_DIM = 256
# Normalization method for the convolution layers.
# Options: "" (no norm), "GN", "SyncBN".
_C.MODEL.ROI_MASK_HEAD.NORM = ""
# Whether to use class agnostic for mask prediction
_C.MODEL.ROI_MASK_HEAD.CLS_AGNOSTIC_MASK = False
# Type of pooling operation applied to the incoming feature map for each RoI
_C.MODEL.ROI_MASK_HEAD.POOLER_TYPE = "ROIAlignV2"


# ---------------------------------------------------------------------------- #
# Keypoint Head
# ---------------------------------------------------------------------------- #
_C.MODEL.ROI_KEYPOINT_HEAD = CN()
_C.MODEL.ROI_KEYPOINT_HEAD.NAME = "KRCNNConvDeconvUpsampleHead"
_C.MODEL.ROI_KEYPOINT_HEAD.POOLER_RESOLUTION = 14
_C.MODEL.ROI_KEYPOINT_HEAD.POOLER_SAMPLING_RATIO = 0
_C.MODEL.ROI_KEYPOINT_HEAD.CONV_DIMS = tuple(512 for _ in range(8))
_C.MODEL.ROI_KEYPOINT_HEAD.NUM_KEYPOINTS = 17  # 17 is the number of keypoints in COCO.

# Images with too few (or no) keypoints are excluded from training.
_C.MODEL.ROI_KEYPOINT_HEAD.MIN_KEYPOINTS_PER_IMAGE = 1
# Normalize by the total number of visible keypoints in the minibatch if True.
# Otherwise, normalize by the total number of keypoints that could ever exist
# in the minibatch.
# The keypoint softmax loss is only calculated on visible keypoints.
# Since the number of visible keypoints can vary significantly between
# minibatches, this has the effect of up-weighting the importance of
# minibatches with few visible keypoints. (Imagine the extreme case of
# only one visible keypoint versus N: in the case of N, each one
# contributes 1/N to the gradient compared to the single keypoint
# determining the gradient direction). Instead, we can normalize the
# loss by the total number of keypoints, if it were the case that all
# keypoints were visible in a full minibatch. (Returning to the example,
# this means that the one visible keypoint contributes as much as each
# of the N keypoints.)
_C.MODEL.ROI_KEYPOINT_HEAD.NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS = True
# Multi-task loss weight to use for keypoints
# Recommended values:
#   - use 1.0 if NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS is True
#   - use 4.0 if NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS is False
_C.MODEL.ROI_KEYPOINT_HEAD.LOSS_WEIGHT = 1.0
# Type of pooling operation applied to the incoming feature map for each RoI
_C.MODEL.ROI_KEYPOINT_HEAD.POOLER_TYPE = "ROIAlignV2"

# ---------------------------------------------------------------------------- #
# Semantic Segmentation Head
# ---------------------------------------------------------------------------- #
_C.MODEL.SEM_SEG_HEAD = CN()
_C.MODEL.SEM_SEG_HEAD.NAME = "SemSegFPNHead"
_C.MODEL.SEM_SEG_HEAD.IN_FEATURES = ["p2", "p3", "p4", "p5"]
# Label in the semantic segmentation ground truth that is ignored, i.e., no loss is calculated for
# the correposnding pixel.
_C.MODEL.SEM_SEG_HEAD.IGNORE_VALUE = 255
# Number of classes in the semantic segmentation head
_C.MODEL.SEM_SEG_HEAD.NUM_CLASSES = 54
# Number of channels in the 3x3 convs inside semantic-FPN heads.
_C.MODEL.SEM_SEG_HEAD.CONVS_DIM = 128
# Outputs from semantic-FPN heads are up-scaled to the COMMON_STRIDE stride.
_C.MODEL.SEM_SEG_HEAD.COMMON_STRIDE = 4
# Normalization method for the convolution layers. Options: "" (no norm), "GN".
_C.MODEL.SEM_SEG_HEAD.NORM = "GN"
_C.MODEL.SEM_SEG_HEAD.LOSS_WEIGHT = 1.0

_C.MODEL.PANOPTIC_FPN = CN()
# Scaling of all losses from instance detection / segmentation head.
_C.MODEL.PANOPTIC_FPN.INSTANCE_LOSS_WEIGHT = 1.0

# options when combining instance & semantic segmentation outputs
_C.MODEL.PANOPTIC_FPN.COMBINE = CN({"ENABLED": True})
_C.MODEL.PANOPTIC_FPN.COMBINE.OVERLAP_THRESH = 0.5
_C.MODEL.PANOPTIC_FPN.COMBINE.STUFF_AREA_LIMIT = 4096
_C.MODEL.PANOPTIC_FPN.COMBINE.INSTANCES_CONFIDENCE_THRESH = 0.5


# ---------------------------------------------------------------------------- #
# RetinaNet Head
# ---------------------------------------------------------------------------- #
_C.MODEL.RETINANET = CN()

# This is the number of foreground classes.
_C.MODEL.RETINANET.NUM_CLASSES = 80

_C.MODEL.RETINANET.IN_FEATURES = ["p3", "p4", "p5", "p6", "p7"]

# Convolutions to use in the cls and bbox tower
# NOTE: this doesn't include the last conv for logits
_C.MODEL.RETINANET.NUM_CONVS = 4

# IoU overlap ratio [bg, fg] for labeling anchors.
# Anchors with < bg are labeled negative (0)
# Anchors  with >= bg and < fg are ignored (-1)
# Anchors with >= fg are labeled positive (1)
_C.MODEL.RETINANET.IOU_THRESHOLDS = [0.4, 0.5]
_C.MODEL.RETINANET.IOU_LABELS = [0, -1, 1]

# Prior prob for rare case (i.e. foreground) at the beginning of training.
# This is used to set the bias for the logits layer of the classifier subnet.
# This improves training stability in the case of heavy class imbalance.
_C.MODEL.RETINANET.PRIOR_PROB = 0.01

# Inference cls score threshold, only anchors with score > INFERENCE_TH are
# considered for inference (to improve speed)
_C.MODEL.RETINANET.SCORE_THRESH_TEST = 0.05
_C.MODEL.RETINANET.TOPK_CANDIDATES_TEST = 1000
_C.MODEL.RETINANET.NMS_THRESH_TEST = 0.5

# Weights on (dx, dy, dw, dh) for normalizing Retinanet anchor regression targets
_C.MODEL.RETINANET.BBOX_REG_WEIGHTS = (1.0, 1.0, 1.0, 1.0)

# Loss parameters
_C.MODEL.RETINANET.FOCAL_LOSS_GAMMA = 2.0
_C.MODEL.RETINANET.FOCAL_LOSS_ALPHA = 0.25
_C.MODEL.RETINANET.SMOOTH_L1_LOSS_BETA = 0.1


# ---------------------------------------------------------------------------- #
# ResNe[X]t options (ResNets = {ResNet, ResNeXt}
# Note that parts of a resnet may be used for both the backbone and the head
# These options apply to both
# ---------------------------------------------------------------------------- #
_C.MODEL.RESNETS = CN()

_C.MODEL.RESNETS.DEPTH = 50
_C.MODEL.RESNETS.OUT_FEATURES = ["res4"]  # res4 for C4 backbone, res2..5 for FPN backbone

# Number of groups to use; 1 ==> ResNet; > 1 ==> ResNeXt
_C.MODEL.RESNETS.NUM_GROUPS = 1

# Options: FrozenBN, GN, "SyncBN", "BN"
_C.MODEL.RESNETS.NORM = "FrozenBN"

# Baseline width of each group.
# Scaling this parameters will scale the width of all bottleneck layers.
_C.MODEL.RESNETS.WIDTH_PER_GROUP = 64

# Place the stride 2 conv on the 1x1 filter
# Use True only for the original MSRA ResNet; use False for C2 and Torch models
_C.MODEL.RESNETS.STRIDE_IN_1X1 = True

# Apply dilation in stage "res5"
_C.MODEL.RESNETS.RES5_DILATION = 1

# Output width of res2. Scaling this parameters will scale the width of all 1x1 convs in ResNet
_C.MODEL.RESNETS.RES2_OUT_CHANNELS = 256
_C.MODEL.RESNETS.STEM_OUT_CHANNELS = 64

# Apply Deformable Convolution in stages
# Specify if apply deform_conv on Res2, Res3, Res4, Res5
_C.MODEL.RESNETS.DEFORM_ON_PER_STAGE = [False, False, False, False]
# Use True to use modulated deform_conv (DeformableV2, https://arxiv.org/abs/1811.11168);
# Use False for DeformableV1.
_C.MODEL.RESNETS.DEFORM_MODULATED = False
# Number of groups in deformable conv.
_C.MODEL.RESNETS.DEFORM_NUM_GROUPS = 1


# ---------------------------------------------------------------------------- #
# Solver
# ---------------------------------------------------------------------------- #
_C.SOLVER = CN()

# See detectron2/solver/build.py for LR scheduler options
_C.SOLVER.LR_SCHEDULER_NAME = "WarmupMultiStepLR"

_C.SOLVER.MAX_ITER = 40000

_C.SOLVER.BASE_LR = 0.001

_C.SOLVER.MOMENTUM = 0.9

_C.SOLVER.WEIGHT_DECAY = 0.0001
# The weight decay that's applied to parameters of normalization layers
# (typically the affine transformation)
_C.SOLVER.WEIGHT_DECAY_NORM = 0.0

_C.SOLVER.GAMMA = 0.1
_C.SOLVER.STEPS = (30000,)

_C.SOLVER.WARMUP_FACTOR = 1.0 / 1000
_C.SOLVER.WARMUP_ITERS = 1000
_C.SOLVER.WARMUP_METHOD = "linear"

_C.SOLVER.CHECKPOINT_PERIOD = 5000

# Number of images per batch across all machines.
# If we have 16 GPUs and IMS_PER_BATCH = 32,
# each GPU will see 2 images per batch.
_C.SOLVER.IMS_PER_BATCH = 16

# Detectron v1 (and previous detection code) used a 2x higher LR and 0 WD for
# biases. This is not useful (at least for recent models). You should avoid
# changing these and they exist only to reproduce Detectron v1 training if
# desired.
_C.SOLVER.BIAS_LR_FACTOR = 1.0
_C.SOLVER.WEIGHT_DECAY_BIAS = _C.SOLVER.WEIGHT_DECAY

# ---------------------------------------------------------------------------- #
# Specific test options
# ---------------------------------------------------------------------------- #
_C.TEST = CN()
# For end-to-end tests to verify the expected accuracy.
# Each item is [task, metric, value, tolerance]
# e.g.: [['bbox', 'AP', 38.5, 0.2]]
_C.TEST.EXPECTED_RESULTS = []
# The period (in terms of steps) to evaluate the model during training.
# Set to 0 to disable.
_C.TEST.EVAL_PERIOD = 0
# The sigmas used to calculate keypoint OKS.
# When empty it will use the defaults in COCO.
# Otherwise it should have the same length as ROI_KEYPOINT_HEAD.NUM_KEYPOINTS.
_C.TEST.KEYPOINT_OKS_SIGMAS = []
# Maximum number of detections to return per image during inference (100 is
# based on the limit established for the COCO dataset).
_C.TEST.DETECTIONS_PER_IMAGE = 100

_C.TEST.AUG = CN({"ENABLED": False})
_C.TEST.AUG.MIN_SIZES = (400, 500, 600, 700, 800, 900, 1000, 1100, 1200)
_C.TEST.AUG.MAX_SIZE = 4000
_C.TEST.AUG.FLIP = True

_C.TEST.PRECISE_BN = CN({"ENABLED": False})
_C.TEST.PRECISE_BN.NUM_ITER = 200

# ---------------------------------------------------------------------------- #
# Misc options
# ---------------------------------------------------------------------------- #
# Directory where output files are written
_C.OUTPUT_DIR = "./output"
# Set seed to negative to fully randomize everything.
# Set seed to positive to use a fixed seed. Note that a fixed seed does not
# guarantee fully deterministic behavior.
_C.SEED = -1
# Benchmark different cudnn algorithms. It has large overhead for about 10k
# iterations. It usually hurts total time, but can benefit for certain models.
_C.CUDNN_BENCHMARK = False
# The period (in terms of steps) for minibatch visualization at train time.
# Set to 0 to disable.
_C.VIS_PERIOD = 0

# global config is for quick hack purposes.
# You can set them in command line or config files,
# and access it with:
#
# from detectron2.config import global_cfg
# print(global_cfg.HACK)
#
# Do not commit any configs into it.
_C.GLOBAL = CN()
_C.GLOBAL.HACK = 1.0
# Out:
# Overwriting ../vilio/py-bottom-up-attention/detectron2/config/defaults.py

# %%
# %%writefile ../vilio/py-bottom-up-attention/detectron2_mscoco_proposal_maxnms.py
# coding=utf-8
# Copyleft 2019 Project LXRT

import argparse
import base64
import csv
import json
import math
import os
import random
import sys
import time
csv.field_size_limit(sys.maxsize)

# import some common libraries
import cv2
import numpy as np
import torch
import tqdm

import detectron2
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.modeling.postprocessing import detector_postprocess
from detectron2.modeling.roi_heads.fast_rcnn import FastRCNNOutputLayers, FastRCNNOutputs


D2_ROOT = os.path.dirname(os.path.dirname(detectron2.__file__)) # Root of detectron2
#DATA_ROOT = os.getenv('COCO_IMG_ROOT', '/ssd-playpen/data/mscoco/images/')

parser = argparse.ArgumentParser()
parser.add_argument('--split', default='train2014', help='train2014, val2014')
parser.add_argument('--batchsize', default=4, type=int, help='batch_size')
parser.add_argument('--model', default='res5', type=str, help='options: "res4", "res5"; features come from)')
parser.add_argument('--weight', default='vg', type=str,
        help='option: mask, obj, vg. mask:mask_rcnn on COCO, obj: faster_rcnn on COCO, vg: faster_rcnn on Visual Genome')

parser.add_argument('--minboxes', default=50, type=int, help='minboxes')
parser.add_argument('--maxboxes', default=50, type=int, help='maxboxes')
parser.add_argument('--dataroot', default='./data/', type=str, help="Path to data root; expects an img folder in the root")

args = parser.parse_args()

from torchvision.ops import nms
from detectron2.structures import Boxes, Instances

def fast_rcnn_inference_single_image(
    boxes, scores, image_shape, score_thresh, nms_thresh, topk_per_image
):
    scores = scores[:, :-1]
    num_bbox_reg_classes = boxes.shape[1] // 4
    # Convert to Boxes to use the `clip` function ...
    boxes = Boxes(boxes.reshape(-1, 4))
    boxes.clip(image_shape)
    boxes = boxes.tensor.view(-1, num_bbox_reg_classes, 4)  # R x C x 4

    # Select max scores
    max_scores, max_classes = scores.max(1)       # R x C --> R
    num_objs = boxes.size(0)
    boxes = boxes.view(-1, 4)
    idxs = torch.arange(num_objs).cpu() * num_bbox_reg_classes + max_classes
    max_boxes = boxes[idxs]     # Select max boxes according to the max scores.

    # Apply NMS
    keep = nms(max_boxes, max_scores, nms_thresh)
    if topk_per_image >= 0:
        keep = keep[:topk_per_image]
    boxes, scores = max_boxes[keep], max_scores[keep]

    result = Instances(image_shape)
    result.pred_boxes = Boxes(boxes)
    result.scores = scores
    result.pred_classes = max_classes[keep]

    return result, keep

def doit(detector, raw_images):
    with torch.no_grad():
        # Preprocessing
        inputs = []
        for raw_image in raw_images:
            image = detector.transform_gen.get_transform(raw_image).apply_image(raw_image)
            image = torch.as_tensor(image.astype("float32").transpose(2, 0, 1))
            inputs.append({"image": image, "height": raw_image.shape[0], "width": raw_image.shape[1]})
        images = detector.model.preprocess_image(inputs)

        # Run Backbone Res1-Res4
        features = detector.model.backbone(images.tensor)

        # Generate proposals with RPN
        proposals, _ = detector.model.proposal_generator(images, features, None)

        # Run RoI head for each proposal (RoI Pooling + Res5)
        proposal_boxes = [x.proposal_boxes for x in proposals]
        features = [features[f] for f in detector.model.roi_heads.in_features]
        box_features = detector.model.roi_heads._shared_roi_transform(
            features, proposal_boxes
        )
        feature_pooled = box_features.mean(dim=[2, 3])  # (sum_proposals, 2048), pooled to 1x1

        # Predict classes and boxes for each proposal.
        if args.weight == "vgattr":
            pred_class_logits, pred_attr_logits, pred_proposal_deltas = detector.model.roi_heads.box_predictor(feature_pooled)
        else:
            pred_class_logits, pred_proposal_deltas = detector.model.roi_heads.box_predictor(feature_pooled)

        rcnn_outputs = FastRCNNOutputs(
            detector.model.roi_heads.box2box_transform,
            pred_class_logits,
            pred_proposal_deltas,
            proposals,
            detector.model.roi_heads.smooth_l1_beta,
        )

        ####
        if args.weight == "vgattr":
            attr_prob = pred_attr_logits[..., :-1].softmax(-1)
            max_attr_prob, max_attr_label = attr_prob.max(-1)

        # Fixed-number NMS
        instances_list, ids_list = [], []
        probs_list = rcnn_outputs.predict_probs()
        boxes_list = rcnn_outputs.predict_boxes()
        for probs, boxes, image_size in zip(probs_list, boxes_list, images.image_sizes):
            for nms_thresh in np.arange(0.3, 1.0, 0.1):
                instances, ids = fast_rcnn_inference_single_image(
                    boxes, probs, image_size,
                    score_thresh=0.2, nms_thresh=nms_thresh, topk_per_image=MAX_BOXES
                )
                if len(ids) >= MIN_BOXES:
                    break
            #####
            if args.weight == "vgattr":
                max_attr_prob = max_attr_prob[ids].detach()
                max_attr_label = max_attr_label[ids].detach()

                instances.attr_scores = max_attr_prob
                instances.attr_classes = max_attr_label

            instances_list.append(instances)
            ids_list.append(ids)


        # Post processing for features
        features_list = feature_pooled.split(rcnn_outputs.num_preds_per_image) # (sum_proposals, 2048) --> [(p1, 2048), (p2, 2048), ..., (pn, 2048)]
        roi_features_list = []
        for ids, features in zip(ids_list, features_list):
            roi_features_list.append(features[ids].detach())

        # Post processing for bounding boxes (rescale to raw_image)
        raw_instances_list = []
        for instances, input_per_image, image_size in zip(
                instances_list, inputs, images.image_sizes
            ):
                height = input_per_image.get("height", image_size[0])
                width = input_per_image.get("width", image_size[1])
                raw_instances = detector_postprocess(instances, height, width)
                raw_instances_list.append(raw_instances)

        return raw_instances_list, roi_features_list


def dump_features(writer, detector, pathXid):
    img_paths, img_ids = zip(*pathXid)
    imgs = [cv2.imread(img_path) for img_path in img_paths]
    instances_list, features_list = doit(detector, imgs)

    for img, img_id, instances, features in zip(imgs, img_ids, instances_list, features_list):
        instances = instances.to('cpu')
        features = features.to('cpu')

        num_objects = len(instances)

        if args.weight == "vgattr":
            item = {
                "img_id": img_id,
                "img_h": img.shape[0],
                "img_w": img.shape[1],
                "objects_id": base64.b64encode(instances.pred_classes.numpy()).decode(),  # int64
                "objects_conf": base64.b64encode(instances.scores.numpy()).decode(),  # float32
                "attrs_id": base64.b64encode(instances.attr_classes.numpy()).decode(),  # int64
                "attrs_conf": base64.b64encode(instances.attr_scores.numpy()).decode(),  # float32
                "num_boxes": num_objects,
                "boxes": base64.b64encode(instances.pred_boxes.tensor.numpy()).decode(),  # float32
                "features": base64.b64encode(features.numpy()).decode()  # float32
            }

        else:
            item = {
                "img_id": img_id,
                "img_h": img.shape[0],
                "img_w": img.shape[1],
                "objects_id": base64.b64encode(instances.pred_classes.numpy()).decode(),  # int64
                "objects_conf": base64.b64encode(instances.scores.numpy()).decode(),  # float32
                "attrs_id": base64.b64encode(np.zeros(num_objects, np.int64)).decode(),  # int64
                "attrs_conf": base64.b64encode(np.zeros(num_objects, np.float32)).decode(),  # float32
                "num_boxes": num_objects,
                "boxes": base64.b64encode(instances.pred_boxes.tensor.numpy()).decode(),  # float32
                "features": base64.b64encode(features.numpy()).decode()  # float32
            }

        writer.writerow(item)


FIELDNAMES = ["img_id", "img_h", "img_w", "objects_id", "objects_conf",
              "attrs_id", "attrs_conf", "num_boxes", "boxes", "features"]
def extract_feat(outfile, detector, pathXid):
    # Check existing images in tsv file.
    wanted_ids = set([image_id[1] for image_id in pathXid])
    found_ids = set()
    if os.path.exists(outfile):
        with open(outfile, 'r') as tsvfile:
            reader = csv.DictReader(tsvfile, delimiter='\t', fieldnames=FIELDNAMES)
            for item in reader:
                found_ids.add(item['img_id'])
    missing = wanted_ids - found_ids

    # Extract features for missing images.
    missing_pathXid = list(filter(lambda x:x[1] in missing, pathXid))
    with open(outfile, 'a') as tsvfile:
        writer = csv.DictWriter(tsvfile, delimiter='\t', fieldnames=FIELDNAMES)
        for start in tqdm.tqdm(range(0, len(pathXid), args.batchsize)):
            pathXid_trunk = pathXid[start: start + args.batchsize]
            dump_features(writer, detector, pathXid_trunk)
            """
            try:
                dump_features(writer, detector, pathXid_trunk)
            except Exception as e:
                print(e)
                break
            """

def load_image_ids(img_root, split_dir):
    """images in the same directory are in the same split"""
    pathXid = []
    img_root = os.path.join(img_root, split_dir)
    for name in os.listdir(img_root):
        idx = name.split(".")[0]
        pathXid.append(
                (
                    os.path.join(img_root, name),
                    idx))
    if split_dir == 'val2014':
        print("Place the features of minival in the front of val2014 tsv.")
        # Put the features of 5000 minival images in front.
        minival_img_ids = set(json.load(open('data/mscoco_imgfeat/coco_minival_img_ids.json')))
        a, b = [], []
        for item in pathXid:
            img_id = item[1]
            if img_id in minival_img_ids:
                a.append(item)
            else:
                b.append(item)
        assert len(a) == 5000
        assert len(a) + len(b) == len(pathXid)
        pathXid = a + b
        assert len(pathXid) == 40504
    return pathXid

def build_model():
    # Build model and load weights.
    if args.weight == 'mask':
        cfg = get_cfg()
        cfg.merge_from_file(os.path.join(
            D2_ROOT, "configs/COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x.yaml"))
        cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
        print("Load the Mask RCNN weight for ResNet101, pretrained on MS COCO segmentation. ")
        cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_101_C4_3x/138363239/model_final_a2914c.pkl"
    elif args.weight == 'obj':
        print("Load the Faster RCNN weight for ResNet101, pretrained on MS COCO detection.")
        cfg = get_cfg()
        cfg.merge_from_file(os.path.join(
            D2_ROOT, "configs/COCO-Detection/faster_rcnn_R_101_C4_3x.yaml"))
        cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
        cfg.MODEL.WEIGHTS = "detectron2://COCO-Detection/faster_rcnn_R_101_C4_3x/138204752/model_final_298dad.pkl"
    elif args.weight == 'vg':
        cfg = get_cfg() # Renew the cfg file
        cfg.merge_from_file(os.path.join(
            D2_ROOT, "configs/VG-Detection/faster_rcnn_R_101_C4_caffemaxpool.yaml"))
        cfg.MODEL.RPN.POST_NMS_TOPK_TEST = 300
        cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.6
        cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2
        cfg.INPUT.MIN_SIZE_TEST = 600
        cfg.INPUT.MAX_SIZE_TEST = 1000
        cfg.MODEL.RPN.NMS_THRESH = 0.7
        # Find a model from detectron2's model zoo. You can either use the https://dl.fbaipublicfiles.... url, or use the following shorthand
        cfg.MODEL.WEIGHTS = "http://nlp.cs.unc.edu/models/faster_rcnn_from_caffe.pkl"
    ### GETATTRS ##
    elif args.weight == 'vgattr':
        cfg = get_cfg()
        cfg.merge_from_file(os.path.join(D2_ROOT, "configs/VG-Detection/faster_rcnn_R_101_C4_attr_caffemaxpool.yaml")) ##
        cfg.MODEL.RPN.POST_NMS_TOPK_TEST = 300
        cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.6
        cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2
        cfg.INPUT.MIN_SIZE_TEST = 600
        cfg.INPUT.MAX_SIZE_TEST = 1000
        cfg.MODEL.RPN.NMS_THRESH = 0.7
        # VG Weight
        cfg.MODEL.WEIGHTS = "http://nlp.cs.unc.edu/models/faster_rcnn_from_caffe_attr.pkl"

    else:
        assert False, "Specified weight does not exist"
    detector = DefaultPredictor(cfg)
    return detector

if __name__ == "__main__":

    # Attrs currently don't work with batchsize > 1
    if args.weight == "vgattr":
        args.batchsize = 1

    DATA_ROOT = os.getenv("IMG", args.dataroot)

    MIN_BOXES = args.minboxes
    MAX_BOXES = args.maxboxes

    pathXid = load_image_ids(DATA_ROOT, args.split)     # Get paths and ids
    detector = build_model()

    output_path = os.path.join(args.dataroot, './hm_{}{}{}.tsv'.format(args.weight, args.minboxes, args.maxboxes))
    extract_feat(output_path, detector, pathXid)

## NOTES:
# Sometimes fails setup depending on the GPU machine
# > You need to make sure cublas is accessible as we are using caffee:
# Copy Cublas to the 10.1 cuda which is in fact used
# !cp -r /usr/local/cuda-10.2/include/*  /usr/local/cuda-10.1/include/
# Out:
# Overwriting ../vilio/py-bottom-up-attention/detectron2_mscoco_proposal_maxnms.py

# %%
import os
import sys
sys.path.append((os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(__file__)))))))
from detectron2_dumb.detectron2 import _C
from collections.abc import Mapping
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# C:\Users\user\PycharmProjects\pythonProject\Citations\vilio

# %%
import os
DATA_ROOT = os.getenv("IMG", './data/')
DATA_ROOT
def load_image_ids(img_root, split_dir):
    """images in the same directory are in the same split"""
    pathXid = []
    img_root = os.path.join(img_root, split_dir)
    for name in os.listdir(img_root):
        idx = name.split(".")[0]
        pathXid.append((os.path.join(img_root, name),idx))
    if split_dir == 'val2014':
        print("Place the features of minival in the front of val2014 tsv.")
        # Put the features of 5000 minival images in front.
        minival_img_ids = set(json.load(open('data/mscoco_imgfeat/coco_minival_img_ids.json')))
        a, b = [], []
        for item in pathXid:
            img_id = item[1]
            if img_id in minival_img_ids:
                a.append(item)
            else:
                b.append(item)
        assert len(a) == 5000
        assert len(a) + len(b) == len(pathXid)
        pathXid = a + b
        assert len(pathXid) == 40504
    return pathXid
pathXid = load_image_ids(DATA_ROOT, 'mcdonalds_switzerland_img')
pathXid
# show images
import matplotlib.pyplot as plt
import cv2
import pandas as pd
data = pd.read_csv('../CLIP_prefix_caption/Model/clip_100up_only200_passlength_12_x_mcdonalds_switzerland/generate_beam_1.csv')
counter = 0
for img_path, img_id in pathXid:
    if img_id in data['image_id'].values:
        counter += 1
counter
# Out:
# 155

# %%
# !cp -r ../input/vilioexample/vilioexample/* ../vilio/py*/data/
# !python ../vilio/py-bottom-up-attention/detectron2_mscoco_proposal_maxnms.py --batchsize 1 --split img --weight vgattr --minboxes 36 --maxboxes 36
# !python ../vilio/py-bottom-up-attention/detectron2_mscoco_proposal_maxnms.py --batchsize 1 --split sonicdrivein_img --weight vgattr --minboxes 36 --maxboxes 36
# !cd ../vilio/py*/data; ls

# %%
# %%writefile new_req.txt
# sacremoses==0.0.43
# pandas==1.1.3
# regex==2020.4.4
# h5py==2.10.0
# filelock==3.0.10
# scipy==1.4.1
# sentencepiece~=0.1.91
# matplotlib==3.2.1
# torch==1.6.0
# tensorflow==2.3.1
# tqdm==4.45.0
# numpy==1.18.1
# six==1.14.0
# packaging==20.1
# wandb==0.10.8
# psutil==5.7.0
# requests==2.23.0
# pytorch_lightning==1.0.4
# ImageHash==4.1.0
# tokenizers~=0.9.2
# transformers==3.5.1 # Required due to some imports in the files under src/vilio/transformers
# torchvision==0.7.0
# jieba==0.42.1
# botocore==1.19.8
# spacy==2.3.2
# boto3==1.16.8
# comet_ml==3.2.5
# dataclasses==0.6
# fairseq==0.9.0
# ftfy==5.8
# fugashi==1.0.5
# ipadic==1.0.0
# lmdb==1.0.0
# Pillow==8.0.1
# py3nvml==0.2.6
# pydantic==1.7.2
# pythainlp==2.2.4
# PyYAML==5.3.1
# scikit_learn==0.23.2
# tensorboardX==2.1
# timeout_decorator==0.4.1
# torchcontrib==0.0.2
# Out:
# Writing new_req.txt

# %%
# !pip install -r new_req.txt
# Out:
# Collecting sacremoses==0.0.43 (from -r new_req.txt (line 1))
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
#      ---------------------------------------- 0.0/883.8 kB ? eta -:--:--
#      -------------------------------------- 883.8/883.8 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas==1.1.3 (from -r new_req.txt (line 2))
#   Downloading pandas-1.1.3.tar.gz (5.2 MB)
#      ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#      ---------------- ----------------------- 2.1/5.2 MB 16.8 MB/s eta 0:00:01
#      ------------------------------------ --- 4.7/5.2 MB 13.0 MB/s eta 0:00:01
#      ---------------------------------------- 5.2/5.2 MB 12.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# WARNING: Ignoring invalid distribution ~orch (C:\Users\user\PycharmProjects\pythonProject\.venv\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [78 lines of output]
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Downloading setuptools-78.1.0-py3-none-any.whl.metadata (6.6 kB)
#   Collecting wheel
#     Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
#   Collecting Cython<3,>=0.29.21
#     Downloading Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
#   Collecting numpy==1.17.3
#     Downloading numpy-1.17.3.zip (6.4 MB)
#        ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#        ---- ----------------------------------- 0.8/6.4 MB 5.6 MB/s eta 0:00:01
#        ---------------- ----------------------- 2.6/6.4 MB 7.5 MB/s eta 0:00:01
#        ------------------------------- -------- 5.0/6.4 MB 8.9 MB/s eta 0:00:01
#        ---------------------------------------- 6.4/6.4 MB 9.1 MB/s eta 0:00:00
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Downloading setuptools-78.1.0-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 1.3/1.3 MB 8.0 MB/s eta 0:00:00
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
#   Downloading Cython-0.29.37-py2.py3-none-any.whl (989 kB)
#      ---------------------------------------- 0.0/989.5 kB ? eta -:--:--
#      ---------------------------------------- 989.5/989.5 kB 6.7 MB/s eta 0:00:00
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     error: subprocess-exited-with-error
#
#     python setup.py bdist_wheel did not run successfully.
#     exit code: 1
#
#     [15 lines of output]
#     Running from numpy source directory.
#     Traceback (most recent call last):
#       File "<string>", line 2, in <module>
#       File "<pip-setuptools-caller>", line 34, in <module>
#       File "C:\Users\user\AppData\Local\Temp\pip-install-1bkic7v2\numpy_8c65cc4756c842c5a184f99fa1fc4e27\setup.py", line 443, in <module>
#         setup_package()
#       File "C:\Users\user\AppData\Local\Temp\pip-install-1bkic7v2\numpy_8c65cc4756c842c5a184f99fa1fc4e27\setup.py", line 422, in setup_package
#         from numpy.distutils.core import setup
#       File "C:\Users\user\AppData\Local\Temp\pip-install-1bkic7v2\numpy_8c65cc4756c842c5a184f99fa1fc4e27\numpy\distutils\core.py", line 26, in <module>
#         from numpy.distutils.command import config, config_compiler, \
#       File "C:\Users\user\AppData\Local\Temp\pip-install-1bkic7v2\numpy_8c65cc4756c842c5a184f99fa1fc4e27\numpy\distutils\command\config.py", line 20, in <module>
#         from numpy.distutils.mingw32ccompiler import generate_manifest
#       File "C:\Users\user\AppData\Local\Temp\pip-install-1bkic7v2\numpy_8c65cc4756c842c5a184f99fa1fc4e27\numpy\distutils\mingw32ccompiler.py", line 34, in <module>
#         from distutils.msvccompiler import get_build_version as get_build_msvc_version
#     ModuleNotFoundError: No module named 'distutils.msvccompiler'
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     error: subprocess-exited-with-error
#
#     python setup.py clean did not run successfully.
#     exit code: 1
#
#     [10 lines of output]
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   ERROR: Failed to build installable wheels for some pyproject.toml based projects (numpy)
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !cp ../vilio/py*/data/example.jsonl ../vilio/data/
# !cp ../vilio/py*/data/hm_vgattr3636.tsv ../vilio/data/HM_img.tsv

# %%
# !ls
# Out:
# __notebook__.ipynb  new_req.txt

# %%
# %%writefile ../vilio/hm_inf.py
import collections
import os

from param import args

import numpy as np

from tqdm import tqdm
import torch
import torch.nn as nn
from torch.utils.data.dataloader import DataLoader

if args.tsv:
    from fts_tsv.hm_data_tsv import HMTorchDataset, HMEvaluator, HMDataset
else:
    from fts_lmdb.hm_data import HMTorchDataset, HMEvaluator, HMDataset

from src.vilio.transformers.optimization import AdamW, get_linear_schedule_with_warmup
from utils.pandas_scripts import clean_data

from entryU import ModelU
from entryX import ModelX
from entryV import ModelV
from entryD import ModelD
from entryO import ModelO

# Two different SWA Methods - https://pytorch.org/blog/pytorch-1.6-now-includes-stochastic-weight-averaging/
if args.swa:
    from torch.optim.swa_utils import AveragedModel, SWALR
    from torch.optim.lr_scheduler import CosineAnnealingLR

if args.contrib:
    from torchcontrib.optim import SWA


# Largely sticking to standards set in LXMERT here
DataTuple = collections.namedtuple("DataTuple", 'dataset loader evaluator')

def get_tuple(splits: str, bs:int, shuffle=False, drop_last=False) -> DataTuple:

    dset =  HMDataset(splits)

    tset = HMTorchDataset(splits)
    evaluator = HMEvaluator(tset)
    data_loader = DataLoader(
        tset, batch_size=bs,
        shuffle=shuffle, num_workers=args.num_workers,
        drop_last=drop_last, pin_memory=True
    )

    return DataTuple(dataset=dset, loader=data_loader, evaluator=evaluator)

class HM:
    def __init__(self):
        
        if args.train is not None:
            self.train_tuple = get_tuple(
                args.train, bs=args.batch_size, shuffle=True, drop_last=False
            )

        if args.valid is not None:
            valid_bsize = 2048 if args.multiGPU else 50
            self.valid_tuple = get_tuple(
                args.valid, bs=valid_bsize,
                shuffle=False, drop_last=False
            )
        else:
            self.valid_tuple = None

        # Select Model, X is default
        if args.model == "X":
            self.model = ModelX(args)
        elif args.model == "V":
            self.model = ModelV(args)
        elif args.model == "U":
            self.model = ModelU(args)
        elif args.model == "D":
            self.model = ModelD(args)
        elif args.model == 'O':
            self.model = ModelO(args)
        else:
            print(args.model, " is not implemented.")

        # Load pre-trained weights from paths
        if args.loadpre is not None:
            self.model.load(args.loadpre)

        # GPU options
        if args.multiGPU:
            self.model.lxrt_encoder.multi_gpu()

        self.model = self.model.cuda()

        # Losses and optimizer
        self.logsoftmax = nn.LogSoftmax(dim=1)
        self.nllloss = nn.NLLLoss()

        if args.train is not None:
            batch_per_epoch = len(self.train_tuple.loader)
            self.t_total = int(batch_per_epoch * args.epochs // args.acc)
            print("Total Iters: %d" % self.t_total)

        def is_backbone(n):
            if "encoder" in n:
                return True
            elif "embeddings" in n:
                return True
            elif "pooler" in n:
                return True
            print("F: ", n)
            return False

        no_decay = ['bias', 'LayerNorm.weight']

        params = list(self.model.named_parameters())
        if args.reg:
            optimizer_grouped_parameters = [
                {"params": [p for n, p in params if is_backbone(n)], "lr": args.lr},
                {"params": [p for n, p in params if not is_backbone(n)], "lr": args.lr * 500},
            ]

            for n, p in self.model.named_parameters():
                print(n)

            self.optim = AdamW(optimizer_grouped_parameters, lr=args.lr)
        else:
            optimizer_grouped_parameters = [
                {'params': [p for n, p in params if not any(nd in n for nd in no_decay)], 'weight_decay': args.wd},
                {'params': [p for n, p in params if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
                ]

            self.optim = AdamW(optimizer_grouped_parameters, lr=args.lr)

        if args.train is not None:
            self.scheduler = get_linear_schedule_with_warmup(self.optim, self.t_total * 0.1, self.t_total)
        
        self.output = args.output
        os.makedirs(self.output, exist_ok=True)

        # SWA Method:
        if args.contrib:
            self.optim = SWA(self.optim, swa_start=self.t_total * 0.75, swa_freq=5, swa_lr=args.lr)

        if args.swa: 
            self.swa_model = AveragedModel(self.model)
            self.swa_start = self.t_total * 0.75
            self.swa_scheduler = SWALR(self.optim, swa_lr=args.lr)

    def train(self, train_tuple, eval_tuple):

        dset, loader, evaluator = train_tuple
        iter_wrapper = (lambda x: tqdm(x, total=len(loader))) if args.tqdm else (lambda x: x)

        print("Batches:", len(loader))

        self.optim.zero_grad()

        best_roc = 0.
        ups = 0
        
        total_loss = 0.

        for epoch in range(args.epochs):
            
            if args.reg:
                if args.model != "X":
                    print(self.model.model.layer_weights)

            id2ans = {}
            id2prob = {}

            for i, (ids, feats, boxes, sent, target) in iter_wrapper(enumerate(loader)):

                if ups == args.midsave:
                    self.save("MID")

                self.model.train()

                if args.swa:
                    self.swa_model.train()
                
                feats, boxes, target = feats.cuda(), boxes.cuda(), target.long().cuda()

                # Model expects visual feats as tuple of feats & boxes
                logit = self.model(sent, (feats, boxes))

                # Note: LogSoftmax does not change order, hence there should be nothing wrong with taking it as our prediction 
                # In fact ROC AUC stays the exact same for logsoftmax / normal softmax, but logsoftmax is better for loss calculation
                # due to stronger penalization & decomplexifying properties (log(a/b) = log(a) - log(b))
                logit = self.logsoftmax(logit)
                score = logit[:, 1]

                if i < 1:
                    print(logit[0, :].detach())
               
                # Note: This loss is the same as CrossEntropy (We splitted it up in logsoftmax & neg. log likelihood loss)
                loss = self.nllloss(logit.view(-1, 2), target.view(-1))

                # Scaling loss by batch size, as we have batches with different sizes, since we do not "drop_last" & dividing by acc for accumulation
                # Not scaling the loss will worsen performance by ~2abs%
                loss = loss * logit.size(0) / args.acc
                loss.backward()

                total_loss += loss.detach().item()

                # Acts as argmax - extracting the higher score & the corresponding index (0 or 1)
                _, predict = logit.detach().max(1)
                # Getting labels for accuracy
                for qid, l in zip(ids, predict.cpu().numpy()):
                    id2ans[qid] = l
                # Getting probabilities for Roc auc
                for qid, l in zip(ids, score.detach().cpu().numpy()):
                    id2prob[qid] = l

                if (i+1) % args.acc == 0:

                    nn.utils.clip_grad_norm_(self.model.parameters(), args.clip)

                    self.optim.step()

                    if (args.swa) and (ups > self.swa_start):
                        self.swa_model.update_parameters(self.model)
                        self.swa_scheduler.step()
                    else:
                        self.scheduler.step()
                    self.optim.zero_grad()

                    ups += 1

                    # Do Validation in between
                    if ups % 250 == 0: 
                        
                        log_str = "\nEpoch(U) %d(%d): Train AC %0.2f RA %0.4f LOSS %0.4f\n" % (epoch, ups, evaluator.evaluate(id2ans)*100, 
                        evaluator.roc_auc(id2prob)*100, total_loss)

                        # Set loss back to 0 after printing it
                        total_loss = 0.

                        if self.valid_tuple is not None:  # Do Validation
                            acc, roc_auc = self.evaluate(eval_tuple)
                            if roc_auc > best_roc:
                                best_roc = roc_auc
                                best_acc = acc
                                # Only save BEST when no midsave is specified to save space
                                #if args.midsave < 0:
                                #    self.save("BEST")

                            log_str += "\nEpoch(U) %d(%d): DEV AC %0.2f RA %0.4f \n" % (epoch, ups, acc*100.,roc_auc*100)
                            log_str += "Epoch(U) %d(%d): BEST AC %0.2f RA %0.4f \n" % (epoch, ups, best_acc*100., best_roc*100.)
    
                        print(log_str, end='')

                        with open(self.output + "/log.log", 'a') as f:
                            f.write(log_str)
                            f.flush()

        if (epoch + 1) == args.epochs:
            if args.contrib:
                self.optim.swap_swa_sgd()

        self.save("LAST" + args.train)

    def predict(self, eval_tuple: DataTuple, dump=None, out_csv=True):

        dset, loader, evaluator = eval_tuple
        id2ans = {}
        id2prob = {}

        for i, datum_tuple in enumerate(loader):

            ids, feats, boxes, sent = datum_tuple[:4]

            self.model.eval()

            if args.swa:
                self.swa_model.eval()

            with torch.no_grad():
                
                feats, boxes = feats.cuda(), boxes.cuda()
                logit = self.model(sent, (feats, boxes))

                # Note: LogSoftmax does not change order, hence there should be nothing wrong with taking it as our prediction
                logit = self.logsoftmax(logit)
                score = logit[:, 1]

                if args.swa:
                    logit = self.swa_model(sent, (feats, boxes))
                    logit = self.logsoftmax(logit)

                _, predict = logit.max(1)

                for qid, l in zip(ids, predict.cpu().numpy()):
                    id2ans[qid] = l

                # Getting probas for Roc Auc
                for qid, l in zip(ids, score.cpu().numpy()):
                    id2prob[qid] = l

        if dump is not None:
            if out_csv == True:
                evaluator.dump_csv(id2ans, id2prob, dump)
            else:
                evaluator.dump_result(id2ans, dump)

        return id2ans, id2prob

    def evaluate(self, eval_tuple: DataTuple, dump=None):
        """Evaluate all data in data_tuple."""
        id2ans, id2prob = self.predict(eval_tuple, dump=dump)

        acc = eval_tuple.evaluator.evaluate(id2ans)
        roc_auc = eval_tuple.evaluator.roc_auc(id2prob)

        return acc, roc_auc

    def save(self, name):
        if args.swa:
            torch.save(self.swa_model.state_dict(),
                    os.path.join(self.output, "%s.pth" % name))
        else:
            torch.save(self.model.state_dict(),
                    os.path.join(self.output, "%s.pth" % name))

    def load(self, path):
        print("Load model from %s" % path)
            
        state_dict = torch.load("%s" % path)
        new_state_dict = {}
        for key, value in state_dict.items():
            # N_averaged is a key in SWA models we cannot load, so we skip it
            if key.startswith("n_averaged"):
                print("n_averaged:", value)
                continue
            # SWA Models will start with module
            if key.startswith("module."):
                new_state_dict[key[len("module."):]] = value
            else:
                new_state_dict[key] = value
        state_dict = new_state_dict
        self.model.load_state_dict(state_dict)

def main():
    # Build Class
    hm = HM()

    # Load Model
    if args.loadfin is not None:
        hm.load(args.loadfin)

    # Train and/or Test:
    if args.train is not None:
        print('Splits in Train data:', hm.train_tuple.dataset.splits)
        if hm.valid_tuple is not None:
            print('Splits in Valid data:', hm.valid_tuple.dataset.splits)
        else:
            print("DO NOT USE VALIDATION")
        hm.train(hm.train_tuple, hm.valid_tuple)

        # If we also test afterwards load the last model
        if args.test is not None:
            hm.load(os.path.join(hm.output, "LAST" + args.train + ".pth"))

    if args.test is not None:
        # We can specify multiple test args e.g. test,test_unseen
        for split in args.test.split(","):
            # Anthing that has no labels:
            if 'test' in split:
                hm.predict(
                    get_tuple(split, bs=args.batch_size,
                            shuffle=False, drop_last=False),
                    dump=os.path.join(args.output, '{}_{}.csv'.format(args.exp, split))
                )
            # Anything else that has labels:
            elif 'dev' in split or 'valid' in split or 'train' in split:
                result = hm.evaluate(
                    get_tuple(split, bs=args.batch_size,
                            shuffle=False, drop_last=False),
                    dump=os.path.join(args.output, '{}_{}.csv'.format(args.exp, split))
                )
                print(result)
            # Same as test - assuming that it has no labels
            else:
                hm.predict(
                    get_tuple(split, bs=args.batch_size,
                            shuffle=False, drop_last=False),
                    dump=os.path.join(args.output, '{}_{}.csv'.format(args.exp, split))
                )
                


if __name__ == "__main__":
    main()
# Out:
# Writing ../vilio/hm_inf.py

# %%
# !cp ../input/testjsonl/example.jsonl ../vilio/data/
# Out:
# 'cp' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import os
data = pd.read_csv(
    '../../Main/Model/20250322_100up_only100_passlength_10_base_0316_oxford_800_8_300_2_ESH_filter_cross_concat_combineLoss/ins/generate_beam_1.csv')

def load_image_ids(img_root, split_dir):
    """images in the same directory are in the same split"""
    pathXid = []
    img_root = os.path.join(img_root, split_dir)
    for name in os.listdir(img_root):
        idx = name.split(".")[0]
        pathXid.append((os.path.join(img_root, name),idx))
    if split_dir == 'val2014':
        print("Place the features of minival in the front of val2014 tsv.")
        # Put the features of 5000 minival images in front.
        minival_img_ids = set(json.load(open('data/mscoco_imgfeat/coco_minival_img_ids.json')))
        a, b = [], []
        for item in pathXid:
            img_id = item[1]
            if img_id in minival_img_ids:
                a.append(item)
            else:
                b.append(item)
        assert len(a) == 5000
        assert len(a) + len(b) == len(pathXid)
        pathXid = a + b
        assert len(pathXid) == 40504
    return pathXid
DATA_ROOT = os.getenv("IMG", './data/')
pathXid = load_image_ids(DATA_ROOT, 'sonicdrivein_img')
counter = 0
for img_path, img_id in pathXid:
    if img_id in data['image_id'].values:
        # remove the image
        counter += 1
        # os.remove(img_path)
counter
# Out:
# 186

# %%
# !python ../vilio/py-bottom-up-attention/detectron2_mscoco_proposal_maxnms.py --batchsize 1 --split sonicdrivein_img --weight vgattr --minboxes 36 --maxboxes 36

# %% [markdown]
# # Score

# %%
import pandas as pd
import json
import torch
# data = pd.read_csv('../CLIP_prefix_caption/Model/clip_100up_only200_passlength_12_MC_base_oxford_800_8_300_82/ins/generate_beam_1.csv')
data = pd.read_csv('../CLIP_prefix_caption/Model/clip_100up_only200_passlength_12_MC_base_oxford_800_8_300_82/ins/generate2_1.csv')
# data = pd.read_csv('../../Main/Model/20250322_100up_only100_passlength_10_base_0316_oxford_800_8_300_2_ESH_filter_cross_concat_combineLoss/generate_beam_1.csv')
# data = pd.read_csv('../../Main/Model/20250322_100up_only100_passlength_10_base_0316_oxford_800_8_300_2_ESH_filter_cross_concat_combineLoss/generate2_1.csv')
# mcdonalds_switzerland_img

jsonFile = []
for i in range(data.shape[0]):
    caption = data['caption'][i].replace('\"', '\'').replace('\n', '').replace('\\', '')
    jsonFile.append(f'\u007b"id": "{data["image_id"][i]}", "img": "sonicdrivein_img/{data["image_id"][i]}.jpg", "text": "{caption}"\u007d')
# path = './data/clip_100up_only200_passlength_12_MC_base_oxford_800_8_300_82_generate_beam_1.jsonl'
path = './data/clip_100up_only200_passlength_12_MC_base_oxford_800_8_300_82_generate2_1.jsonl'
with open(path, 'w', encoding='utf-8') as f:
    for item in jsonFile:
        f.write("%s\n" % item)
jsonFile
# Out:
# ['{"id": "mcdonalds_switzerland_835", "img": "sonicdrivein_img/mcdonalds_switzerland_835.jpg", "text": "🎮 hot news for the gamers out there: with x-mas magic run, you can win amazing prizes every day as of 17h 19h : 🎁."}',
#  '{"id": "mcdonalds_switzerland_2025", "img": "sonicdrivein_img/mcdonalds_switzerland_2025.jpg", "text": "coffee in one hand, confidence in the other."}',
#  '{"id": "mcdonalds_switzerland_364", "img": "sonicdrivein_img/mcdonalds_switzerland_364.jpg", "text": "did you know? paper always wins in the video game."}',
#  '{"id": "mcdonalds_switzerland_693", "img": "sonicdrivein_img/mcdonalds_switzerland_693.jpg", "text": "real friends share the same taste in burgers."}',
#  '{"id": "mcdonalds_switzerland_236", "img": "sonicdrivein_img/mcdonalds_switzerland_236.jpg", "text": "the big tasty challenge: try looking at this without producing any saliva😜 🍔 🤔 who agrees? hap </s># bigtastytuesday# yummy# food# challenge# easy# way# life# mcdonalds# mcdo# foodie# picoftheday# switzerland"}',
#  '{"id": "mcdonalds_switzerland_617", "img": "sonicdrivein_img/mcdonalds_switzerland_617.jpg", "text": "today is international kissing day and we wish you a wonderful day."}',
#  '{"id": "mcdonalds_switzerland_1886", "img": "sonicdrivein_img/mcdonalds_switzerland_1886.jpg", "text": "new: come and try our new chocolate bacon sundae topping."}',
#  '{"id": "mcdonalds_switzerland_654", "img": "sonicdrivein_img/mcdonalds_switzerland_654.jpg", "text": "congratulations to simon rieckhoff for a fantastic season highlighted by a swiss champion title and a participation at the youth olympic games in august."}',
#  '{"id": "mcdonalds_switzerland_645", "img": "sonicdrivein_img/mcdonalds_switzerland_645.jpg", "text": "big mac lover? then you should try our new chicken big mac which will be available as of tomorrow in the restaurants."}',
#  '{"id": "mcdonalds_switzerland_293", "img": "sonicdrivein_img/mcdonalds_switzerland_293.jpg", "text": "i know there are talented artists among you."}',
#  '{"id": "mcdonalds_switzerland_480", "img": "sonicdrivein_img/mcdonalds_switzerland_480.jpg", "text": "today, we celebrate friendship day 🥳 🎉."}',
#  '{"id": "mcdonalds_switzerland_794", "img": "sonicdrivein_img/mcdonalds_switzerland_794.jpg", "text": "we all have a hamburglar in our lives."}',
#  '{"id": "mcdonalds_switzerland_1985", "img": "sonicdrivein_img/mcdonalds_switzerland_1985.jpg", "text": "no matter what time it is ... i \'m always craving for the big mac."}',
#  '{"id": "mcdonalds_switzerland_31", "img": "sonicdrivein_img/mcdonalds_switzerland_31.jpg", "text": "episode 2/8 – nervous and struggling to find the right outfit? sounds like getting ready for a date with a nervous ex- the one and only celineprecina."}',
#  '{"id": "mcdonalds_switzerland_2031", "img": "sonicdrivein_img/mcdonalds_switzerland_2031.jpg", "text": "new: come and try our new chocolate bacon sundae topping."}',
#  '{"id": "mcdonalds_switzerland_16", "img": "sonicdrivein_img/mcdonalds_switzerland_16.jpg", "text": "congratulations@ xenia_blumin, you should get a medal for reel \'s transition 😉 your suporters from mcdonald \'s pratteln took the video challenge, but you are still the n°1 🥇 so you are n°1 🥇 happy# reel# worldemojiday#"}',
#  '{"id": "mcdonalds_switzerland_828", "img": "sonicdrivein_img/mcdonalds_switzerland_828.jpg", "text": "no matter what time it is or will be, there’ s always room for a mcdo menu 😉 🍔# mcdonalds# mcdo# burger# food# good# summer# mcdonalds# mcd# fries# picoftheday# switzerland# bestoftheday# likes#"}',
#  '{"id": "mcdonalds_switzerland_230", "img": "sonicdrivein_img/mcdonalds_switzerland_230.jpg", "text": "okay, this time we \'re not kidding."}',
#  '{"id": "mcdonalds_switzerland_699", "img": "sonicdrivein_img/mcdonalds_switzerland_699.jpg", "text": "we’ ll surprise your loved ones with an extra slice of christmas 🎁."}',
#  '{"id": "mcdonalds_switzerland_448", "img": "sonicdrivein_img/mcdonalds_switzerland_448.jpg", "text": "our big mac 🍔 is now even better with a softer bun, more sauce and the beef grilled together with the onions."}',
#  '{"id": "mcdonalds_switzerland_677", "img": "sonicdrivein_img/mcdonalds_switzerland_677.jpg", "text": "just imagine ... would you like this chocolate sauce for your chicken mcnuggets? today is a 🍫 craving day and that \'s what we’ re looking for 😉 🎁# mcdonalds# mcdo# tasty# food# summer# mcdonalds# mcnuggets# foodie# pico"}',
#  '{"id": "mcdonalds_switzerland_411", "img": "sonicdrivein_img/mcdonalds_switzerland_411.jpg", "text": "# repost@ mcdonaldsleb ・・・ it \'s time to say thank you for the great pic@ __mgxt__, our drink suits you so well."}',
#  '{"id": "mcdonalds_switzerland_227", "img": "sonicdrivein_img/mcdonalds_switzerland_227.jpg", "text": "who would you like to compliment? tag them in the comments and let them know 🥰 so they \'re not the only ones to recognize you."}',
#  '{"id": "mcdonalds_switzerland_632", "img": "sonicdrivein_img/mcdonalds_switzerland_632.jpg", "text": "tell us what your favorite movie is while savouring one of our delicious menus, and get the chance to win a sky movie pass of 20x tickets for a sky movie in vienna, buenos aires and cape town."}',
#  '{"id": "mcdonalds_switzerland_419", "img": "sonicdrivein_img/mcdonalds_switzerland_419.jpg", "text": "sharing is caring 💞🍓🍌# loveatfirstsip# smoothie# strawberry# banana# drink# fresh# mccafe# mcdo# mcdonalds# refreshing# mms# mandms# mundmms# mundmms# mundmms# mundmms# mundm"}',
#  '{"id": "mcdonalds_switzerland_1882", "img": "sonicdrivein_img/mcdonalds_switzerland_1882.jpg", "text": "make the most of your time at home to brush up on your burger knowledge."}',
#  '{"id": "mcdonalds_switzerland_1219", "img": "sonicdrivein_img/mcdonalds_switzerland_1219.jpg", "text": "the crying, fighting and worrying about who \'s getting the last chicken mcnuggets has come to an end: the chicken mcnuggets® are back 🍦🍳."}',
#  '{"id": "mcdonalds_switzerland_655", "img": "sonicdrivein_img/mcdonalds_switzerland_655.jpg", "text": "ready for the weekend? one more day to go and it \'s a very important one: the international world egg day 🥚 🍳 start it off right now and discover the incredible egg giveaways in our app 🤩 ! 😍# internationaleggday# mcdonalds# mcdo# eggday# monday"}',
#  '{"id": "mcdonalds_switzerland_69", "img": "sonicdrivein_img/mcdonalds_switzerland_69.jpg", "text": "i don’ t remember what i \'ve ordered…can you help me? 👀 tell me in the comments below where this mcdonald’ s is."}',
#  '{"id": "mcdonalds_switzerland_1132", "img": "sonicdrivein_img/mcdonalds_switzerland_1132.jpg", "text": "our amazing sunset offers are back, every day as of 17h."}',
#  '{"id": "mcdonalds_switzerland_528", "img": "sonicdrivein_img/mcdonalds_switzerland_528.jpg", "text": "our# bacon clubhouse is available with beef or chicken."}',
#  '{"id": "mcdonalds_switzerland_1883", "img": "sonicdrivein_img/mcdonalds_switzerland_1883.jpg", "text": "happy# worldemojiday, but we still have a lot of cookies ... what about you?# mcdonalds# mcdo# chocolate# donut# food# summer# yummy# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie# p"}',
#  '{"id": "mcdonalds_switzerland_1215", "img": "sonicdrivein_img/mcdonalds_switzerland_1215.jpg", "text": "just imagine ... would you like this chocolate sauce for your chicken mcnuggets? today is a 🍫 craving day and that \'s what we’ re looking for 😉 🍟# mcdonalds# mcdo# tasty# food# summer# mcdonalds# mcnuggets# foodie# pico"}',
#  '{"id": "mcdonalds_switzerland_716", "img": "sonicdrivein_img/mcdonalds_switzerland_716.jpg", "text": "big mac lover? then you should try our new chicken big mac which will be available as of tomorrow in the restaurants."}',
#  '{"id": "mcdonalds_switzerland_713", "img": "sonicdrivein_img/mcdonalds_switzerland_713.jpg", "text": "happy# worldemojiday, but we still have a lot of good reasons to celebrate you 😉# mcdo# happy# worldemojiday# fries# burgers# food# goodnews# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie#"}',
#  '{"id": "mcdonalds_switzerland_172", "img": "sonicdrivein_img/mcdonalds_switzerland_172.jpg", "text": "like this picture if you \'re lucky enough to also go on holidays with# mccafe?# mcdonalds# mcdo# happy# holidays# cappuccino# chocolate# picoftheday# switzerland# lucky# mcdonalds# mcdo# picoftheday# switzerland# sw"}',
#  '{"id": "mcdonalds_switzerland_168", "img": "sonicdrivein_img/mcdonalds_switzerland_168.jpg", "text": "in 2022, together with your help, we will reduce 200t of plastic pollution and 3d bbq restaurants will open their restaurants again."}',
#  '{"id": "mcdonalds_switzerland_19", "img": "sonicdrivein_img/mcdonalds_switzerland_19.jpg", "text": "something big is coming this summer: our first ever mcdive on the lake zürich letzipark."}',
#  '{"id": "mcdonalds_switzerland_1138", "img": "sonicdrivein_img/mcdonalds_switzerland_1138.jpg", "text": "eggscuse me please, i have a mouthful of delicious things to do."}',
#  '{"id": "mcdonalds_switzerland_2039", "img": "sonicdrivein_img/mcdonalds_switzerland_2039.jpg", "text": "congratulations to@ officialgshc on reaching the champions league semi-finals and looking forward to seeing you soon in our restaurants."}',
#  '{"id": "mcdonalds_switzerland_27", "img": "sonicdrivein_img/mcdonalds_switzerland_27.jpg", "text": "i don’ t remember what i \'ve ordered…can you help me? 👀 tell me in the comments below where this mcdonald’ s is."}',
#  '{"id": "mcdonalds_switzerland_1842", "img": "sonicdrivein_img/mcdonalds_switzerland_1842.jpg", "text": "# repost@ mcdonaldsleb ・・・ it \'s time to say thank you for the pic@ __mgxt__, our drink suits you so well."}',
#  '{"id": "mcdonalds_switzerland_625", "img": "sonicdrivein_img/mcdonalds_switzerland_625.jpg", "text": "when@ kevin_mbabu tries our hotter, juicier and fresher burgers 🍔 🍟, we only see stars in his eyes 🤩."}',
#  '{"id": "mcdonalds_switzerland_1203", "img": "sonicdrivein_img/mcdonalds_switzerland_1203.jpg", "text": "fries with sauce on the go🍟? no problem at all with our new# burger fr 1.- hamburger fr 1.- available now in all our restaurants# mcdonalds# mcdo# burger# food# delicious# mcdonalds# refreshing# daim# toblerone# mms# mandms#"}',
#  '{"id": "mcdonalds_switzerland_793", "img": "sonicdrivein_img/mcdonalds_switzerland_793.jpg", "text": "kitchens are open for you to enjoy with our new# mccafe salty products."}',
#  '{"id": "mcdonalds_switzerland_623", "img": "sonicdrivein_img/mcdonalds_switzerland_623.jpg", "text": "our amazing sunset offers are back, every day as of 17h : 03h:00 in all mcdonald \'s restaurants in switzerland and the principality of liechtenstein."}',
#  '{"id": "mcdonalds_switzerland_768", "img": "sonicdrivein_img/mcdonalds_switzerland_768.jpg", "text": "when you can’ t decide because you \'ve ordered chicken mcnuggets® ... which one will you choose? 🍔 🤔 # mcdo# burger# mcnuggets# food# bestoftheday# likes# igvideo# foodstagram# foodie# picoftheday# switzerland"}',
#  '{"id": "mcdonalds_switzerland_205", "img": "sonicdrivein_img/mcdonalds_switzerland_205.jpg", "text": "what \'s happening behind the counter? switch sides to find out."}',
#  '{"id": "mcdonalds_switzerland_683", "img": "sonicdrivein_img/mcdonalds_switzerland_683.jpg", "text": "the minions sneaked into the happy meal® box."}',
#  '{"id": "mcdonalds_switzerland_673", "img": "sonicdrivein_img/mcdonalds_switzerland_673.jpg", "text": "sorry… not available right now 😎.# mcdonalds# mcdo# coffee# good# drink# good# good# yummy# picoftheday# switzerland# bestoftheday# likes# igvideo# food# good# good# yummy# picoftheday# swissmutt"}',
#  '{"id": "mcdonalds_switzerland_737", "img": "sonicdrivein_img/mcdonalds_switzerland_737.jpg", "text": "so, so, soooooo ... am i going to get you this time? who can figure out where this mcdonald \'s is, huh? happy easter to all of you 💛🍔# easter_nati# easter_wednesday# yummy# food# summer# mcdonalds"}',
#  '{"id": "mcdonalds_switzerland_748", "img": "sonicdrivein_img/mcdonalds_switzerland_748.jpg", "text": "⚠️ contest ⚠️ small moments make a big difference ⚠️ what do you do to make a big difference for the people you love🥰? let us know in the comments and participate in the raffle to get 10x50 chf mcdonald \'s vouchers 💰."}',
#  '{"id": "mcdonalds_switzerland_271", "img": "sonicdrivein_img/mcdonalds_switzerland_271.jpg", "text": "our take-away bag."}',
#  '{"id": "mcdonalds_switzerland_165", "img": "sonicdrivein_img/mcdonalds_switzerland_165.jpg", "text": "we \'re sure you \'ll hit the slopes in style this year ... any tips on where to find best ones ❄️☀️🏂?# mccafe# mcdonalds# mcdo# tasty# monday# cappuccino# chocolate# spring# fresh# monday# mcdo#"}',
#  '{"id": "mcdonalds_switzerland_2035", "img": "sonicdrivein_img/mcdonalds_switzerland_2035.jpg", "text": "get your coca-cola™ glass 🖤 this week it comes with a glass 🖤 medium menu."}',
#  '{"id": "mcdonalds_switzerland_13", "img": "sonicdrivein_img/mcdonalds_switzerland_13.jpg", "text": "festival season is well underway in switzerland, and i \'ve remixed a few iconic movie posters with mcdonald \'s flavor."}',
#  '{"id": "mcdonalds_switzerland_220", "img": "sonicdrivein_img/mcdonalds_switzerland_220.jpg", "text": "our crew members are so proud of their restaurants that they played along and sent me their photos to challenge you."}',
#  '{"id": "mcdonalds_switzerland_285", "img": "sonicdrivein_img/mcdonalds_switzerland_285.jpg", "text": "everyone has their own way of celebrating \'the beatles\'. i \'m not leaving you the last of my chicken mcnuggets® ... but i am sure you \'d already know how to enjoy your life 😉# thelesundissipiac# mcdo# mcdonalds# tasty# burgers# burgersday# sw"}',
#  '{"id": "mcdonalds_switzerland_1196", "img": "sonicdrivein_img/mcdonalds_switzerland_1196.jpg", "text": "that moment when you get your food prepared with care and love from a whole family ❤️🍁# shrimps# rmhc# rmhc# rmhc# burger# foodie# mcdonalds# mcdo# burgerday# switzerland# bestoftheday# likes# igvideo#"}',
#  '{"id": "mcdonalds_switzerland_735", "img": "sonicdrivein_img/mcdonalds_switzerland_735.jpg", "text": "i know you \'ve been practicing crosswords with your grandma every sunday: it \'s time to challenge yourself ... and what \'s in your bag? 😉 🍔# mcdonalds# mcdo# burger# mcnuggets# foodie# picoftheday# switzerland# bestoftheday"}',
#  '{"id": "mcdonalds_switzerland_1197", "img": "sonicdrivein_img/mcdonalds_switzerland_1197.jpg", "text": "not everyone enjoys frying as much as we do 😎 🍔 but we do n\'t want to share it with you 😉 🤘 so enjoy your time together with us 😉# friesforlife# mcdonalds# telenovela# mandarin# toblerone# mms# mandoline# mund"}',
#  '{"id": "mcdonalds_switzerland_90", "img": "sonicdrivein_img/mcdonalds_switzerland_90.jpg", "text": "we are there for you ... 🍟 🍔 especially when you \'re having one of these busy days 😉@ friedahodel# mcdelivery# youlivewedeliver@ bysofiaziani# mcfamilyswitzerland# wedding# weddingday# mcfamilyswitzerland# weddingday"}',
#  '{"id": "mcdonalds_switzerland_596", "img": "sonicdrivein_img/mcdonalds_switzerland_596.jpg", "text": "aaaah, the new coca-cola glasses in 4 neon colors are here."}',
#  '{"id": "mcdonalds_switzerland_6", "img": "sonicdrivein_img/mcdonalds_switzerland_6.jpg", "text": "when mcdonald’ s makes your choice difficult, it \'s easier than finding your ootd app 📱 ... and there’ s always room for a mcdo snoop."}',
#  '{"id": "mcdonalds_switzerland_169", "img": "sonicdrivein_img/mcdonalds_switzerland_169.jpg", "text": "when you go to mcdonald \'s to get your regular menu and find out that there is a spicy mcchicken®& that the spicy mcchicken® is spicy, you \'re not the lucky person 😉 🍔# lucky# mcdonalds# mcdo# spicy# food# foodie# pico"}',
#  '{"id": "mcdonalds_switzerland_248", "img": "sonicdrivein_img/mcdonalds_switzerland_248.jpg", "text": "the chicken wings are back 🍗 🥳 this week you can get the limited mcveggie menu spicy chicken wings with bacon, with or without."}',
#  '{"id": "mcdonalds_switzerland_628", "img": "sonicdrivein_img/mcdonalds_switzerland_628.jpg", "text": "also impatiently waiting for x-mas? 🎄 here is one delicious box you can open early ... 😉 🎁# xmas# yummy# christmas# yummy# imlovinit# mcdo# xmas# yummy# imlovinit# foodie# picoftheday# sw"}',
#  '{"id": "mcdonalds_switzerland_721", "img": "sonicdrivein_img/mcdonalds_switzerland_721.jpg", "text": "me stepping into the long weekend right now 😍 who \'s looking forward to this? 😍 mcdonald \'s switzerland and dcl are giving you the opportunity to compete in the live-streamed mcdonald \'s virtual drone grand prix lake zurich, in switzerland this october."}',
#  '{"id": "mcdonalds_switzerland_662", "img": "sonicdrivein_img/mcdonalds_switzerland_662.jpg", "text": "veggie vs."}',
#  '{"id": "mcdonalds_switzerland_59", "img": "sonicdrivein_img/mcdonalds_switzerland_59.jpg", "text": "# yummy# donut# food# delicious# summer# yummy# donut# summer# snack# summer# mccafe# mcdo# mcdonalds# refreshing# daim# toblerone# mms# mandms# mundmms# mundmms# mundmms# mundmms#"}',
#  '{"id": "mcdonalds_switzerland_457", "img": "sonicdrivein_img/mcdonalds_switzerland_457.jpg", "text": "so."}',
#  '{"id": "mcdonalds_switzerland_7", "img": "sonicdrivein_img/mcdonalds_switzerland_7.jpg", "text": "we are there for you ... 🍟 🍔 especially when you \'re having one of these busy days ... 🧑\u200d💻 🤱 🏃# youlivewedeliver@ bysofiaziani_australia0804 ## imlovinit# youlivewedeliver"}',
#  '{"id": "mcdonalds_switzerland_117", "img": "sonicdrivein_img/mcdonalds_switzerland_117.jpg", "text": "the perfect match or too hot to handle? try it now in the comments or swipe to find out."}',
#  '{"id": "mcdonalds_switzerland_2014", "img": "sonicdrivein_img/mcdonalds_switzerland_2014.jpg", "text": "are you missing the hour too much? maybe a delicious beverage or pastry will cheer you up;)# food# timechange# sleepy# sleepy# sleepy# foodie# picoftheday# switzerland# bestoftheday# likes# foodstagram# foodie# picoftheday# swissm"}',
#  '{"id": "mcdonalds_switzerland_774", "img": "sonicdrivein_img/mcdonalds_switzerland_774.jpg", "text": "today is international kissing day and i want to tell you something through your big tasty tongue."}',
#  '{"id": "mcdonalds_switzerland_45", "img": "sonicdrivein_img/mcdonalds_switzerland_45.jpg", "text": "on the way to one of our restaurants? just register with “ socialpass ” or “ mindful check-in ” and enjoy."}',
#  '{"id": "mcdonalds_switzerland_2016", "img": "sonicdrivein_img/mcdonalds_switzerland_2016.jpg", "text": "you know the drill: good taste knows no age."}',
#  '{"id": "mcdonalds_switzerland_1612", "img": "sonicdrivein_img/mcdonalds_switzerland_1612.jpg", "text": "we \'re lovin\' you 🍔🍟 even in busy times at home 😉@ friedahodel# mcdelivery# youlivewedeliver@ bysofiaziani# wedding# weddingday# mcdelivery# youlivewedeliver# youlivewedeliversof"}',
#  '{"id": "mcdonalds_switzerland_1904", "img": "sonicdrivein_img/mcdonalds_switzerland_1904.jpg", "text": "we \'re proud to support the stars of tomorrow and to encourage them on their way to the top."}',
#  '{"id": "mcdonalds_switzerland_237", "img": "sonicdrivein_img/mcdonalds_switzerland_237.jpg", "text": "have you tried our must haves ts and deluxe? are n\'t they delicious?# burger# delicious# mcdonalds# mcdo# burger# deluxe# food# delicious# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo# foodie# foodie#"}',
#  '{"id": "mcdonalds_switzerland_262", "img": "sonicdrivein_img/mcdonalds_switzerland_262.jpg", "text": "the mcraclette only stays available for another week."}',
#  '{"id": "mcdonalds_switzerland_122", "img": "sonicdrivein_img/mcdonalds_switzerland_122.jpg", "text": "the royals are back today: discover the royal tzatziki and the mcchicken basilic."}',
#  '{"id": "mcdonalds_switzerland_163", "img": "sonicdrivein_img/mcdonalds_switzerland_163.jpg", "text": "finally, it was time to fall in love again with our coca-cola™ glass 🖤."}',
#  '{"id": "mcdonalds_switzerland_234", "img": "sonicdrivein_img/mcdonalds_switzerland_234.jpg", "text": "she picked up litter, she won the clean-up-day jackpot of 3\'000 chf."}',
#  '{"id": "mcdonalds_switzerland_50", "img": "sonicdrivein_img/mcdonalds_switzerland_50.jpg", "text": "no matter the weather- we go out in style 😎 🤠 who knows the feeling?# sundae# food# summer# mcdonalds# mcdo# tasty# summer# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie# pico"}',
#  '{"id": "mcdonalds_switzerland_902", "img": "sonicdrivein_img/mcdonalds_switzerland_902.jpg", "text": "who knows that feeling of happiness? 🤩 finding leftover fries in your bag after your meal 🙌? are n\'t we all a little inspired by that 🍔?# smallmomentsmakeabigdifference# food# happiness# snack# foodie# picoftheday# switzerland# bestoft"}',
#  '{"id": "mcdonalds_switzerland_1591", "img": "sonicdrivein_img/mcdonalds_switzerland_1591.jpg", "text": "# repost@ mcdonaldsleb ・・・ it just goes with every meal# fries# mcdonalds# lebanon# yummy# donut# food# yummy# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo# foodie# foodie"}',
#  '{"id": "mcdonalds_switzerland_681", "img": "sonicdrivein_img/mcdonalds_switzerland_681.jpg", "text": "sorry… not available right now 😎.# mcdo# mcdonalds# coffee# coffee# drink# good# yummy# picoftheday# switzerland# bestoftheday# likes# igvideo# food# goodnews# picoftheday# swissmuttheday# bestofthed"}',
#  '{"id": "mcdonalds_switzerland_2032", "img": "sonicdrivein_img/mcdonalds_switzerland_2032.jpg", "text": "# repost@ mcdonaldsleb ・・・ it \'s not easy, but it \'s fun# mcdonalds# lebanon# yummy# donut# food# art# lol# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo# food"}',
#  '{"id": "mcdonalds_switzerland_732", "img": "sonicdrivein_img/mcdonalds_switzerland_732.jpg", "text": "congratulations emma and team european soccer team on reaching the round of 16 ! 🏀: today \'s the match and we \'re excited to hear back from you 🥰: link in bio for bio."}',
#  '{"id": "mcdonalds_switzerland_904", "img": "sonicdrivein_img/mcdonalds_switzerland_904.jpg", "text": "fries with sauce on the go🍟? no problem, just right 💛# burgerfries# food# goodnews# picoftheday# switzerland# goodnewsday# swissmcdelivery# foodstagram# foodie# picoftheday# swissmcdel"}',
#  '{"id": "mcdonalds_switzerland_52", "img": "sonicdrivein_img/mcdonalds_switzerland_52.jpg", "text": "in 2022, together with your help, we will reduce 200t of plastic pollution and 3d bbq restaurants will open in switzerland this summer."}',
#  '{"id": "mcdonalds_switzerland_201", "img": "sonicdrivein_img/mcdonalds_switzerland_201.jpg", "text": "are you ready? ⚠️ something big is coming this summer: our first ever mcdive on the lake zürich stadelhofen."}',
#  '{"id": "mcdonalds_switzerland_273", "img": "sonicdrivein_img/mcdonalds_switzerland_273.jpg", "text": "what will you choose with our summer deals? thanks to@ f."}',
#  '{"id": "mcdonalds_switzerland_668", "img": "sonicdrivein_img/mcdonalds_switzerland_668.jpg", "text": "the closer it gets, the better it gets – the homestyle honey mustard veggie."}',
#  '{"id": "mcdonalds_switzerland_118", "img": "sonicdrivein_img/mcdonalds_switzerland_118.jpg", "text": "you know the drill: good taste knows no age."}',
#  '{"id": "mcdonalds_switzerland_864", "img": "sonicdrivein_img/mcdonalds_switzerland_864.jpg", "text": "this is not how it \'s done at our# mccafe, we promise it \'s nothing like it \'s supposed to be."}',
#  '{"id": "mcdonalds_switzerland_173", "img": "sonicdrivein_img/mcdonalds_switzerland_173.jpg", "text": "if you were wondering if the enchanting mermaids eat plankton,@ kknovaa gives you the answer: they eat filet-o-fish® . . . . . . . .# mermaids# food# enchanting# mermaids# foodie# picoftheday# switzerland"}',
#  '{"id": "mcdonalds_switzerland_332", "img": "sonicdrivein_img/mcdonalds_switzerland_332.jpg", "text": "tag the lucky person that gets to share the chicken mcnuggets with you 🍔🍟 🥤."}',
#  '{"id": "mcdonalds_switzerland_715", "img": "sonicdrivein_img/mcdonalds_switzerland_715.jpg", "text": "just imagine ... would you like this chocolate sauce for your chicken mcnuggets? today is a 🍫 craving day and that \'s why we are reducing 200t of plastic this year, thanks to sustainable happy meal toys and our mcnuggets."}',
#  '{"id": "mcdonalds_switzerland_242", "img": "sonicdrivein_img/mcdonalds_switzerland_242.jpg", "text": "wow, that \'s really funny ... what \'s your way to make a big mac without a big mac?# bigmacfries# burgerlover# classic# food# funny# yt# funny# foodie# mcdo# mcdonalds# refreshing# daim# toblerone# mms# mand"}',
#  '{"id": "mcdonalds_switzerland_1209", "img": "sonicdrivein_img/mcdonalds_switzerland_1209.jpg", "text": "finally, it was time to fall in love again 🍔!!! from the bottom of our hearts, we wish you the best day 😉 🎁# fallforlove# mcdonalds# telenovela# sunset# love# summer# mcdo# mcdonalds# telenovela# summer#"}',
#  '{"id": "mcdonalds_switzerland_1934", "img": "sonicdrivein_img/mcdonalds_switzerland_1934.jpg", "text": "we are there for you ... 🍔🍟 even in busy times at home 🏡# mcdelivery# youlivewedeliver@ bysofiaziani0804 </s># mcfamilyswitzerland# youlivewedeliver@ bysofiaziani0804 </s>#"}',
#  '{"id": "mcdonalds_switzerland_1168", "img": "sonicdrivein_img/mcdonalds_switzerland_1168.jpg", "text": "even@ stevemerson shows us what ‘ s in his bag."}',
#  '{"id": "mcdonalds_switzerland_1656", "img": "sonicdrivein_img/mcdonalds_switzerland_1656.jpg", "text": "congratulations emma and team mate </s> on reaching the champions league semi-finals and looking forward to seeing you soon in our livestream."}',
#  '{"id": "mcdonalds_switzerland_712", "img": "sonicdrivein_img/mcdonalds_switzerland_712.jpg", "text": "keep cool and try our new iced caffè latte.( while listening to our ice cool playlist of course ➡️ link in bio). link in bio."}',
#  '{"id": "mcdonalds_switzerland_682", "img": "sonicdrivein_img/mcdonalds_switzerland_682.jpg", "text": "even@ stevemerson shows us what ‘ s in his bag."}',
#  '{"id": "mcdonalds_switzerland_859", "img": "sonicdrivein_img/mcdonalds_switzerland_859.jpg", "text": "if you \'re team spicy chicken mcnuggets®: hurry up ... they will soon be gone."}',
#  '{"id": "mcdonalds_switzerland_265", "img": "sonicdrivein_img/mcdonalds_switzerland_265.jpg", "text": "sometimes, you \'re not as broke as you think you are ... especially if you use the mymcdonald \'s bonus program in the app .. i do n\'t think so myself."}',
#  '{"id": "mcdonalds_switzerland_1", "img": "sonicdrivein_img/mcdonalds_switzerland_1.jpg", "text": "here’ s how you can get the limited mcdonald’ s merch💥🔥: ➡️ all you have to do is:- get the mcdonald’ s app📱- subscribe to the loyalty program🫶🏼- collect points and exchange them for real money in"}',
#  '{"id": "mcdonalds_switzerland_180", "img": "sonicdrivein_img/mcdonalds_switzerland_180.jpg", "text": "our challenge is getting harder and we \'re trying to get you this time 😉 🍔 believe us, the bigger the better 😉 🤔 have you tried our bigger fries yet?# smallmomentsmakeabigdifference# mcdonalds# mcdo# friesforlife# picoftheday#"}',
#  '{"id": "mcdonalds_switzerland_2001", "img": "sonicdrivein_img/mcdonalds_switzerland_2001.jpg", "text": "one big tasty, 12 variations – which one is your favorite? 🍔 😍 🤤 which one is your # 🍔 🤤? tag your favorite below in the comments."}',
#  '{"id": "mcdonalds_switzerland_60", "img": "sonicdrivein_img/mcdonalds_switzerland_60.jpg", "text": "it’ s time to say thank you for donating to the ronald mcdonald house charities and therefore keeping families close in their homes."}',
#  '{"id": "mcdonalds_switzerland_181", "img": "sonicdrivein_img/mcdonalds_switzerland_181.jpg", "text": "when@ malbuner bacon is so popular that they even have their own emoji."}',
#  '{"id": "mcdonalds_switzerland_395", "img": "sonicdrivein_img/mcdonalds_switzerland_395.jpg", "text": "we’ ll surprise your loved ones with an extra slice of christmas 🎁."}',
#  '{"id": "mcdonalds_switzerland_1037", "img": "sonicdrivein_img/mcdonalds_switzerland_1037.jpg", "text": "no matter the mean of transport, you \'re always in a hurry to get there when you \'re hungry."}',
#  '{"id": "mcdonalds_switzerland_481", "img": "sonicdrivein_img/mcdonalds_switzerland_481.jpg", "text": "are you missing the hour too much? maybe a delicious beverage or pastry will cheer you up;)# food# timechange# sleepy# sleepy# sleepy# foodie# picoftheday# switzerland# bestoftheday# likes# foodstagram# foodie# picoftheday# swissm"}',
#  '{"id": "mcdonalds_switzerland_203", "img": "sonicdrivein_img/mcdonalds_switzerland_203.jpg", "text": "the crying, fighting and worrying about who \'s getting the last chicken mcnuggets has come to an end: the chicken mcnuggets® the are back."}',
#  '{"id": "mcdonalds_switzerland_330", "img": "sonicdrivein_img/mcdonalds_switzerland_330.jpg", "text": "⚠️warning- crispy content ⚠️don’ t look at it too closely if you’ re hungry right now 😉 🍔# friedahodel# friedahodel# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo#"}',
#  '{"id": "mcdonalds_switzerland_1962", "img": "sonicdrivein_img/mcdonalds_switzerland_1962.jpg", "text": "not only can you taste our chicken big mac but you can also dream of big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac"}',
#  '{"id": "mcdonalds_switzerland_2020", "img": "sonicdrivein_img/mcdonalds_switzerland_2020.jpg", "text": "our# bacon clubhouse is available with beef or chicken."}',
#  '{"id": "mcdonalds_switzerland_868", "img": "sonicdrivein_img/mcdonalds_switzerland_868.jpg", "text": "remember this date: 1st of march."}',
#  '{"id": "mcdonalds_switzerland_256", "img": "sonicdrivein_img/mcdonalds_switzerland_256.jpg", "text": "what \'s happening behind the counter? switch sides to find out."}',
#  '{"id": "mcdonalds_switzerland_1948", "img": "sonicdrivein_img/mcdonalds_switzerland_1948.jpg", "text": "winter is coming and we’ re picking up: enjoy your favorite burgers summer run and enjoy the sounds of autumn in our restaurants."}',
#  '{"id": "mcdonalds_switzerland_730", "img": "sonicdrivein_img/mcdonalds_switzerland_730.jpg", "text": "another difficult monday? sleep in a little longer and come have breakfast with us( we \'re sure you \'ll hit the slopes very soon).# mcdonalds# mcdo# breakfast# mcd# mcdonalds# breakfast# yummy# donut# foodie# picoftheday# switzerland#"}',
#  '{"id": "mcdonalds_switzerland_129", "img": "sonicdrivein_img/mcdonalds_switzerland_129.jpg", "text": "today’ s the international day of# friendship."}',
#  '{"id": "mcdonalds_switzerland_691", "img": "sonicdrivein_img/mcdonalds_switzerland_691.jpg", "text": "winter is coming and so is the famous chocolate triangle on top of a delicious ice cream: the mcflurry ® toblerone ® toblerone® toblerone® 🤤 ... which one will you choose?;-)# mcdonalds# mcdo# toblerone# toblerone# icecream# summer"}',
#  '{"id": "mcdonalds_switzerland_232", "img": "sonicdrivein_img/mcdonalds_switzerland_232.jpg", "text": "🔥 sauce it up 🚨 this is your last chance to win one of our exclusive snipes x mcdonald’ s collab pieces."}',
#  '{"id": "mcdonalds_switzerland_178", "img": "sonicdrivein_img/mcdonalds_switzerland_178.jpg", "text": "🔥 sauce it up 🚨 this is your last chance to win one of our exclusive snipes x mcdonald’ s collab pieces."}',
#  '{"id": "mcdonalds_switzerland_153", "img": "sonicdrivein_img/mcdonalds_switzerland_153.jpg", "text": "🔥 sauce it up 🚨 this is your last chance to win one of our exclusive snipes x mcdonald’ s collab pieces."}',
#  '{"id": "mcdonalds_switzerland_586", "img": "sonicdrivein_img/mcdonalds_switzerland_586.jpg", "text": "ready for the weekend? one more day to go and it \'s a very important one: the international world egg day 🥚 🍳 start it off with a delicious egg from# mccafe# mcdonalds# mcdo# eggday# monday# cappuccino# chocolate# spring# fresh#"}',
#  '{"id": "mcdonalds_switzerland_637", "img": "sonicdrivein_img/mcdonalds_switzerland_637.jpg", "text": "not sure if i \'m ready for you, but i am ready to share my best mcdonald \'s moment with you 🍔🍟."}',
#  '{"id": "mcdonalds_switzerland_377", "img": "sonicdrivein_img/mcdonalds_switzerland_377.jpg", "text": "what \'s happening behind the counter? switch sides to find out."}',
#  '{"id": "mcdonalds_switzerland_360", "img": "sonicdrivein_img/mcdonalds_switzerland_360.jpg", "text": "i \'m lovin\' it."}',
#  '{"id": "mcdonalds_switzerland_73", "img": "sonicdrivein_img/mcdonalds_switzerland_73.jpg", "text": "you do n\'t have to be a ski pro to enjoy our sundae cailler \'s chocolate slopes🍦😍# sundae# chocolate# slopes# mcdonalds# mcdo# slopes# picoftheday# switzerland# bestoftheday# likes# igvideo# foodie# pico"}',
#  '{"id": "mcdonalds_switzerland_2006", "img": "sonicdrivein_img/mcdonalds_switzerland_2006.jpg", "text": "our take-away bag."}',
#  '{"id": "mcdonalds_switzerland_222", "img": "sonicdrivein_img/mcdonalds_switzerland_222.jpg", "text": "happy celebration tonight and see you tomorrow for the lazy 1st of january mcdelivery order 😜 🎁# lazy# mcdelivery# lazy# mcdelivery# surprise# you# lucky# first# mcdelivery# first# lucky# first# first# lucky# first# first#"}',
#  '{"id": "mcdonalds_switzerland_1056", "img": "sonicdrivein_img/mcdonalds_switzerland_1056.jpg", "text": "aura +5000 if you bring the fr."}',
#  '{"id": "mcdonalds_switzerland_54", "img": "sonicdrivein_img/mcdonalds_switzerland_54.jpg", "text": "there’ s a new chick on the block."}',
#  '{"id": "mcdonalds_switzerland_696", "img": "sonicdrivein_img/mcdonalds_switzerland_696.jpg", "text": "we think these are pretty hot news 😎."}',
#  '{"id": "mcdonalds_switzerland_1871", "img": "sonicdrivein_img/mcdonalds_switzerland_1871.jpg", "text": "photography is as simple as this reel."}',
#  '{"id": "mcdonalds_switzerland_251", "img": "sonicdrivein_img/mcdonalds_switzerland_251.jpg", "text": "today, around the world, we celebrate friendship."}',
#  '{"id": "mcdonalds_switzerland_706", "img": "sonicdrivein_img/mcdonalds_switzerland_706.jpg", "text": "the chicken wings are back 🍗 🥳 this week, grab the chicken wings for only 1.- and only until further notice."}',
#  '{"id": "mcdonalds_switzerland_81", "img": "sonicdrivein_img/mcdonalds_switzerland_81.jpg", "text": "we are here for you ... 🍔🍟 even in busy times at home 🏡# mcdelivery# youlivewedeliver@ bysofiaziani0804 </s> </s> </s> </s> </s> </s> </s> </s> </s>"}',
#  '{"id": "mcdonalds_switzerland_80", "img": "sonicdrivein_img/mcdonalds_switzerland_80.jpg", "text": "we are there for you ... 🍔🍟 even in busy times at home 🏡# mcdelivery# youlivewedeliver@ bysofiaziani_alfonso started his# bbqaroundtheworld trip from# switzerland to# sydney."}',
#  '{"id": "mcdonalds_switzerland_672", "img": "sonicdrivein_img/mcdonalds_switzerland_672.jpg", "text": "⚠️ contest ⚠️ small moments make a big difference ⚠️ so make an impact today and thank you for your participation: your bffs had a great day 💙# smallmomentsmakeabigdifference# mcdonalds# mcdo# smallmomentsmakeabigdifference"}',
#  '{"id": "mcdonalds_switzerland_725", "img": "sonicdrivein_img/mcdonalds_switzerland_725.jpg", "text": "⚠️ to win big, you need to be able to wear our hats."}',
#  '{"id": "mcdonalds_switzerland_769", "img": "sonicdrivein_img/mcdonalds_switzerland_769.jpg", "text": "the beauty of not standing in line and waiting on your order."}',
#  '{"id": "mcdonalds_switzerland_676", "img": "sonicdrivein_img/mcdonalds_switzerland_676.jpg", "text": "with the big mac, there \'s never enough space left ... 🍟 😩# bigmac# mac# food# timechange# goodnews# mac# foodie# refreshing# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie# refreshing#"}',
#  '{"id": "mcdonalds_switzerland_22", "img": "sonicdrivein_img/mcdonalds_switzerland_22.jpg", "text": "it’ s international burger day, so enjoy it to the last bite."}',
#  '{"id": "mcdonalds_switzerland_714", "img": "sonicdrivein_img/mcdonalds_switzerland_714.jpg", "text": "our big mac- stayin’ fabulous forever and always."}',
#  '{"id": "mcdonalds_switzerland_447", "img": "sonicdrivein_img/mcdonalds_switzerland_447.jpg", "text": "the crying, fighting and worrying about who \'s getting the last chicken mcnuggets has come to an end: the chicken mcnuggets® are back."}',
#  '{"id": "mcdonalds_switzerland_858", "img": "sonicdrivein_img/mcdonalds_switzerland_858.jpg", "text": "it’ s time to say thank you for donating to the ronald mcdonald house charities and therefore keeping families close in their hearts."}',
#  '{"id": "mcdonalds_switzerland_746", "img": "sonicdrivein_img/mcdonalds_switzerland_746.jpg", "text": "one big tasty, 12 variations – which one is your favorite? 🍔 😍 🤤 which one is your favorite? 🤤 thanks to@ sh."}',
#  '{"id": "mcdonalds_switzerland_2026", "img": "sonicdrivein_img/mcdonalds_switzerland_2026.jpg", "text": "craving for fries? comment 🤏 to try to get one of these 🍟 🍔 📚."}']

# %%
# [json.loads(jline) for jline in open(path, "r", encoding="utf-8").read().split('\n')]
import json
pre = ''
raw_data = []
with open(path, 'r', encoding='utf-8')as f:
    for line in f:
        if '\u007d' not in line:
            pre += line
            continue
        if pre:
            line = pre + line
            pre = ''
        print(line)
        data = json.loads(line)
        raw_data.append(data)
        print("=====")
print("Load %d data from split(s)." % (len(raw_data)))
# Out:
# {"id": "mcdonalds_switzerland_835", "img": "sonicdrivein_img/mcdonalds_switzerland_835.jpg", "text": "🎮 hot news for the gamers out there: with x-mas magic run, you can win amazing prizes every day as of 17h 19h : 🎁."}
#
# =====
# {"id": "mcdonalds_switzerland_2025", "img": "sonicdrivein_img/mcdonalds_switzerland_2025.jpg", "text": "coffee in one hand, confidence in the other."}
#
# =====
# {"id": "mcdonalds_switzerland_364", "img": "sonicdrivein_img/mcdonalds_switzerland_364.jpg", "text": "did you know? paper always wins in the video game."}
#
# =====
# {"id": "mcdonalds_switzerland_693", "img": "sonicdrivein_img/mcdonalds_switzerland_693.jpg", "text": "real friends share the same taste in burgers."}
#
# =====
# {"id": "mcdonalds_switzerland_236", "img": "sonicdrivein_img/mcdonalds_switzerland_236.jpg", "text": "the big tasty challenge: try looking at this without producing any saliva😜 🍔 🤔 who agrees? hap </s># bigtastytuesday# yummy# food# challenge# easy# way# life# mcdonalds# mcdo# foodie# picoftheday# switzerland"}
#
# =====
# {"id": "mcdonalds_switzerland_617", "img": "sonicdrivein_img/mcdonalds_switzerland_617.jpg", "text": "today is international kissing day and we wish you a wonderful day."}
#
# =====
# {"id": "mcdonalds_switzerland_1886", "img": "sonicdrivein_img/mcdonalds_switzerland_1886.jpg", "text": "new: come and try our new chocolate bacon sundae topping."}
#
# =====
# {"id": "mcdonalds_switzerland_654", "img": "sonicdrivein_img/mcdonalds_switzerland_654.jpg", "text": "congratulations to simon rieckhoff for a fantastic season highlighted by a swiss champion title and a participation at the youth olympic games in august."}
#
# =====
# {"id": "mcdonalds_switzerland_645", "img": "sonicdrivein_img/mcdonalds_switzerland_645.jpg", "text": "big mac lover? then you should try our new chicken big mac which will be available as of tomorrow in the restaurants."}
#
# =====
# {"id": "mcdonalds_switzerland_293", "img": "sonicdrivein_img/mcdonalds_switzerland_293.jpg", "text": "i know there are talented artists among you."}
#
# =====
# {"id": "mcdonalds_switzerland_480", "img": "sonicdrivein_img/mcdonalds_switzerland_480.jpg", "text": "today, we celebrate friendship day 🥳 🎉."}
#
# =====
# {"id": "mcdonalds_switzerland_794", "img": "sonicdrivein_img/mcdonalds_switzerland_794.jpg", "text": "we all have a hamburglar in our lives."}
#
# =====
# {"id": "mcdonalds_switzerland_1985", "img": "sonicdrivein_img/mcdonalds_switzerland_1985.jpg", "text": "no matter what time it is ... i 'm always craving for the big mac."}
#
# =====
# {"id": "mcdonalds_switzerland_31", "img": "sonicdrivein_img/mcdonalds_switzerland_31.jpg", "text": "episode 2/8 – nervous and struggling to find the right outfit? sounds like getting ready for a date with a nervous ex- the one and only celineprecina."}
#
# =====
# {"id": "mcdonalds_switzerland_2031", "img": "sonicdrivein_img/mcdonalds_switzerland_2031.jpg", "text": "new: come and try our new chocolate bacon sundae topping."}
#
# =====
# {"id": "mcdonalds_switzerland_16", "img": "sonicdrivein_img/mcdonalds_switzerland_16.jpg", "text": "congratulations@ xenia_blumin, you should get a medal for reel 's transition 😉 your suporters from mcdonald 's pratteln took the video challenge, but you are still the n°1 🥇 so you are n°1 🥇 happy# reel# worldemojiday#"}
#
# =====
# {"id": "mcdonalds_switzerland_828", "img": "sonicdrivein_img/mcdonalds_switzerland_828.jpg", "text": "no matter what time it is or will be, there’ s always room for a mcdo menu 😉 🍔# mcdonalds# mcdo# burger# food# good# summer# mcdonalds# mcd# fries# picoftheday# switzerland# bestoftheday# likes#"}
#
# =====
# {"id": "mcdonalds_switzerland_230", "img": "sonicdrivein_img/mcdonalds_switzerland_230.jpg", "text": "okay, this time we 're not kidding."}
#
# =====
# {"id": "mcdonalds_switzerland_699", "img": "sonicdrivein_img/mcdonalds_switzerland_699.jpg", "text": "we’ ll surprise your loved ones with an extra slice of christmas 🎁."}
#
# =====
# {"id": "mcdonalds_switzerland_448", "img": "sonicdrivein_img/mcdonalds_switzerland_448.jpg", "text": "our big mac 🍔 is now even better with a softer bun, more sauce and the beef grilled together with the onions."}
#
# =====
# {"id": "mcdonalds_switzerland_677", "img": "sonicdrivein_img/mcdonalds_switzerland_677.jpg", "text": "just imagine ... would you like this chocolate sauce for your chicken mcnuggets? today is a 🍫 craving day and that 's what we’ re looking for 😉 🎁# mcdonalds# mcdo# tasty# food# summer# mcdonalds# mcnuggets# foodie# pico"}
#
# =====
# {"id": "mcdonalds_switzerland_411", "img": "sonicdrivein_img/mcdonalds_switzerland_411.jpg", "text": "# repost@ mcdonaldsleb ・・・ it 's time to say thank you for the great pic@ __mgxt__, our drink suits you so well."}
#
# =====
# {"id": "mcdonalds_switzerland_227", "img": "sonicdrivein_img/mcdonalds_switzerland_227.jpg", "text": "who would you like to compliment? tag them in the comments and let them know 🥰 so they 're not the only ones to recognize you."}
#
# =====
# {"id": "mcdonalds_switzerland_632", "img": "sonicdrivein_img/mcdonalds_switzerland_632.jpg", "text": "tell us what your favorite movie is while savouring one of our delicious menus, and get the chance to win a sky movie pass of 20x tickets for a sky movie in vienna, buenos aires and cape town."}
#
# =====
# {"id": "mcdonalds_switzerland_419", "img": "sonicdrivein_img/mcdonalds_switzerland_419.jpg", "text": "sharing is caring 💞🍓🍌# loveatfirstsip# smoothie# strawberry# banana# drink# fresh# mccafe# mcdo# mcdonalds# refreshing# mms# mandms# mundmms# mundmms# mundmms# mundmms# mundm"}
#
# =====
# {"id": "mcdonalds_switzerland_1882", "img": "sonicdrivein_img/mcdonalds_switzerland_1882.jpg", "text": "make the most of your time at home to brush up on your burger knowledge."}
#
# =====
# {"id": "mcdonalds_switzerland_1219", "img": "sonicdrivein_img/mcdonalds_switzerland_1219.jpg", "text": "the crying, fighting and worrying about who 's getting the last chicken mcnuggets has come to an end: the chicken mcnuggets® are back 🍦🍳."}
#
# =====
# {"id": "mcdonalds_switzerland_655", "img": "sonicdrivein_img/mcdonalds_switzerland_655.jpg", "text": "ready for the weekend? one more day to go and it 's a very important one: the international world egg day 🥚 🍳 start it off right now and discover the incredible egg giveaways in our app 🤩 ! 😍# internationaleggday# mcdonalds# mcdo# eggday# monday"}
#
# =====
# {"id": "mcdonalds_switzerland_69", "img": "sonicdrivein_img/mcdonalds_switzerland_69.jpg", "text": "i don’ t remember what i 've ordered…can you help me? 👀 tell me in the comments below where this mcdonald’ s is."}
#
# =====
# {"id": "mcdonalds_switzerland_1132", "img": "sonicdrivein_img/mcdonalds_switzerland_1132.jpg", "text": "our amazing sunset offers are back, every day as of 17h."}
#
# =====
# {"id": "mcdonalds_switzerland_528", "img": "sonicdrivein_img/mcdonalds_switzerland_528.jpg", "text": "our# bacon clubhouse is available with beef or chicken."}
#
# =====
# {"id": "mcdonalds_switzerland_1883", "img": "sonicdrivein_img/mcdonalds_switzerland_1883.jpg", "text": "happy# worldemojiday, but we still have a lot of cookies ... what about you?# mcdonalds# mcdo# chocolate# donut# food# summer# yummy# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie# p"}
#
# =====
# {"id": "mcdonalds_switzerland_1215", "img": "sonicdrivein_img/mcdonalds_switzerland_1215.jpg", "text": "just imagine ... would you like this chocolate sauce for your chicken mcnuggets? today is a 🍫 craving day and that 's what we’ re looking for 😉 🍟# mcdonalds# mcdo# tasty# food# summer# mcdonalds# mcnuggets# foodie# pico"}
#
# =====
# {"id": "mcdonalds_switzerland_716", "img": "sonicdrivein_img/mcdonalds_switzerland_716.jpg", "text": "big mac lover? then you should try our new chicken big mac which will be available as of tomorrow in the restaurants."}
#
# =====
# {"id": "mcdonalds_switzerland_713", "img": "sonicdrivein_img/mcdonalds_switzerland_713.jpg", "text": "happy# worldemojiday, but we still have a lot of good reasons to celebrate you 😉# mcdo# happy# worldemojiday# fries# burgers# food# goodnews# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie#"}
#
# =====
# {"id": "mcdonalds_switzerland_172", "img": "sonicdrivein_img/mcdonalds_switzerland_172.jpg", "text": "like this picture if you 're lucky enough to also go on holidays with# mccafe?# mcdonalds# mcdo# happy# holidays# cappuccino# chocolate# picoftheday# switzerland# lucky# mcdonalds# mcdo# picoftheday# switzerland# sw"}
#
# =====
# {"id": "mcdonalds_switzerland_168", "img": "sonicdrivein_img/mcdonalds_switzerland_168.jpg", "text": "in 2022, together with your help, we will reduce 200t of plastic pollution and 3d bbq restaurants will open their restaurants again."}
#
# =====
# {"id": "mcdonalds_switzerland_19", "img": "sonicdrivein_img/mcdonalds_switzerland_19.jpg", "text": "something big is coming this summer: our first ever mcdive on the lake zürich letzipark."}
#
# =====
# {"id": "mcdonalds_switzerland_1138", "img": "sonicdrivein_img/mcdonalds_switzerland_1138.jpg", "text": "eggscuse me please, i have a mouthful of delicious things to do."}
#
# =====
# {"id": "mcdonalds_switzerland_2039", "img": "sonicdrivein_img/mcdonalds_switzerland_2039.jpg", "text": "congratulations to@ officialgshc on reaching the champions league semi-finals and looking forward to seeing you soon in our restaurants."}
#
# =====
# {"id": "mcdonalds_switzerland_27", "img": "sonicdrivein_img/mcdonalds_switzerland_27.jpg", "text": "i don’ t remember what i 've ordered…can you help me? 👀 tell me in the comments below where this mcdonald’ s is."}
#
# =====
# {"id": "mcdonalds_switzerland_1842", "img": "sonicdrivein_img/mcdonalds_switzerland_1842.jpg", "text": "# repost@ mcdonaldsleb ・・・ it 's time to say thank you for the pic@ __mgxt__, our drink suits you so well."}
#
# =====
# {"id": "mcdonalds_switzerland_625", "img": "sonicdrivein_img/mcdonalds_switzerland_625.jpg", "text": "when@ kevin_mbabu tries our hotter, juicier and fresher burgers 🍔 🍟, we only see stars in his eyes 🤩."}
#
# =====
# {"id": "mcdonalds_switzerland_1203", "img": "sonicdrivein_img/mcdonalds_switzerland_1203.jpg", "text": "fries with sauce on the go🍟? no problem at all with our new# burger fr 1.- hamburger fr 1.- available now in all our restaurants# mcdonalds# mcdo# burger# food# delicious# mcdonalds# refreshing# daim# toblerone# mms# mandms#"}
#
# =====
# {"id": "mcdonalds_switzerland_793", "img": "sonicdrivein_img/mcdonalds_switzerland_793.jpg", "text": "kitchens are open for you to enjoy with our new# mccafe salty products."}
#
# =====
# {"id": "mcdonalds_switzerland_623", "img": "sonicdrivein_img/mcdonalds_switzerland_623.jpg", "text": "our amazing sunset offers are back, every day as of 17h : 03h:00 in all mcdonald 's restaurants in switzerland and the principality of liechtenstein."}
#
# =====
# {"id": "mcdonalds_switzerland_768", "img": "sonicdrivein_img/mcdonalds_switzerland_768.jpg", "text": "when you can’ t decide because you 've ordered chicken mcnuggets® ... which one will you choose? 🍔 🤔 # mcdo# burger# mcnuggets# food# bestoftheday# likes# igvideo# foodstagram# foodie# picoftheday# switzerland"}
#
# =====
# {"id": "mcdonalds_switzerland_205", "img": "sonicdrivein_img/mcdonalds_switzerland_205.jpg", "text": "what 's happening behind the counter? switch sides to find out."}
#
# =====
# {"id": "mcdonalds_switzerland_683", "img": "sonicdrivein_img/mcdonalds_switzerland_683.jpg", "text": "the minions sneaked into the happy meal® box."}
#
# =====
# {"id": "mcdonalds_switzerland_673", "img": "sonicdrivein_img/mcdonalds_switzerland_673.jpg", "text": "sorry… not available right now 😎.# mcdonalds# mcdo# coffee# good# drink# good# good# yummy# picoftheday# switzerland# bestoftheday# likes# igvideo# food# good# good# yummy# picoftheday# swissmutt"}
#
# =====
# {"id": "mcdonalds_switzerland_737", "img": "sonicdrivein_img/mcdonalds_switzerland_737.jpg", "text": "so, so, soooooo ... am i going to get you this time? who can figure out where this mcdonald 's is, huh? happy easter to all of you 💛🍔# easter_nati# easter_wednesday# yummy# food# summer# mcdonalds"}
#
# =====
# {"id": "mcdonalds_switzerland_748", "img": "sonicdrivein_img/mcdonalds_switzerland_748.jpg", "text": "⚠️ contest ⚠️ small moments make a big difference ⚠️ what do you do to make a big difference for the people you love🥰? let us know in the comments and participate in the raffle to get 10x50 chf mcdonald 's vouchers 💰."}
#
# =====
# {"id": "mcdonalds_switzerland_271", "img": "sonicdrivein_img/mcdonalds_switzerland_271.jpg", "text": "our take-away bag."}
#
# =====
# {"id": "mcdonalds_switzerland_165", "img": "sonicdrivein_img/mcdonalds_switzerland_165.jpg", "text": "we 're sure you 'll hit the slopes in style this year ... any tips on where to find best ones ❄️☀️🏂?# mccafe# mcdonalds# mcdo# tasty# monday# cappuccino# chocolate# spring# fresh# monday# mcdo#"}
#
# =====
# {"id": "mcdonalds_switzerland_2035", "img": "sonicdrivein_img/mcdonalds_switzerland_2035.jpg", "text": "get your coca-cola™ glass 🖤 this week it comes with a glass 🖤 medium menu."}
#
# =====
# {"id": "mcdonalds_switzerland_13", "img": "sonicdrivein_img/mcdonalds_switzerland_13.jpg", "text": "festival season is well underway in switzerland, and i 've remixed a few iconic movie posters with mcdonald 's flavor."}
#
# =====
# {"id": "mcdonalds_switzerland_220", "img": "sonicdrivein_img/mcdonalds_switzerland_220.jpg", "text": "our crew members are so proud of their restaurants that they played along and sent me their photos to challenge you."}
#
# =====
# {"id": "mcdonalds_switzerland_285", "img": "sonicdrivein_img/mcdonalds_switzerland_285.jpg", "text": "everyone has their own way of celebrating 'the beatles'. i 'm not leaving you the last of my chicken mcnuggets® ... but i am sure you 'd already know how to enjoy your life 😉# thelesundissipiac# mcdo# mcdonalds# tasty# burgers# burgersday# sw"}
#
# =====
# {"id": "mcdonalds_switzerland_1196", "img": "sonicdrivein_img/mcdonalds_switzerland_1196.jpg", "text": "that moment when you get your food prepared with care and love from a whole family ❤️🍁# shrimps# rmhc# rmhc# rmhc# burger# foodie# mcdonalds# mcdo# burgerday# switzerland# bestoftheday# likes# igvideo#"}
#
# =====
# {"id": "mcdonalds_switzerland_735", "img": "sonicdrivein_img/mcdonalds_switzerland_735.jpg", "text": "i know you 've been practicing crosswords with your grandma every sunday: it 's time to challenge yourself ... and what 's in your bag? 😉 🍔# mcdonalds# mcdo# burger# mcnuggets# foodie# picoftheday# switzerland# bestoftheday"}
#
# =====
# {"id": "mcdonalds_switzerland_1197", "img": "sonicdrivein_img/mcdonalds_switzerland_1197.jpg", "text": "not everyone enjoys frying as much as we do 😎 🍔 but we do n't want to share it with you 😉 🤘 so enjoy your time together with us 😉# friesforlife# mcdonalds# telenovela# mandarin# toblerone# mms# mandoline# mund"}
#
# =====
# {"id": "mcdonalds_switzerland_90", "img": "sonicdrivein_img/mcdonalds_switzerland_90.jpg", "text": "we are there for you ... 🍟 🍔 especially when you 're having one of these busy days 😉@ friedahodel# mcdelivery# youlivewedeliver@ bysofiaziani# mcfamilyswitzerland# wedding# weddingday# mcfamilyswitzerland# weddingday"}
#
# =====
# {"id": "mcdonalds_switzerland_596", "img": "sonicdrivein_img/mcdonalds_switzerland_596.jpg", "text": "aaaah, the new coca-cola glasses in 4 neon colors are here."}
#
# =====
# {"id": "mcdonalds_switzerland_6", "img": "sonicdrivein_img/mcdonalds_switzerland_6.jpg", "text": "when mcdonald’ s makes your choice difficult, it 's easier than finding your ootd app 📱 ... and there’ s always room for a mcdo snoop."}
#
# =====
# {"id": "mcdonalds_switzerland_169", "img": "sonicdrivein_img/mcdonalds_switzerland_169.jpg", "text": "when you go to mcdonald 's to get your regular menu and find out that there is a spicy mcchicken®& that the spicy mcchicken® is spicy, you 're not the lucky person 😉 🍔# lucky# mcdonalds# mcdo# spicy# food# foodie# pico"}
#
# =====
# {"id": "mcdonalds_switzerland_248", "img": "sonicdrivein_img/mcdonalds_switzerland_248.jpg", "text": "the chicken wings are back 🍗 🥳 this week you can get the limited mcveggie menu spicy chicken wings with bacon, with or without."}
#
# =====
# {"id": "mcdonalds_switzerland_628", "img": "sonicdrivein_img/mcdonalds_switzerland_628.jpg", "text": "also impatiently waiting for x-mas? 🎄 here is one delicious box you can open early ... 😉 🎁# xmas# yummy# christmas# yummy# imlovinit# mcdo# xmas# yummy# imlovinit# foodie# picoftheday# sw"}
#
# =====
# {"id": "mcdonalds_switzerland_721", "img": "sonicdrivein_img/mcdonalds_switzerland_721.jpg", "text": "me stepping into the long weekend right now 😍 who 's looking forward to this? 😍 mcdonald 's switzerland and dcl are giving you the opportunity to compete in the live-streamed mcdonald 's virtual drone grand prix lake zurich, in switzerland this october."}
#
# =====
# {"id": "mcdonalds_switzerland_662", "img": "sonicdrivein_img/mcdonalds_switzerland_662.jpg", "text": "veggie vs."}
#
# =====
# {"id": "mcdonalds_switzerland_59", "img": "sonicdrivein_img/mcdonalds_switzerland_59.jpg", "text": "# yummy# donut# food# delicious# summer# yummy# donut# summer# snack# summer# mccafe# mcdo# mcdonalds# refreshing# daim# toblerone# mms# mandms# mundmms# mundmms# mundmms# mundmms#"}
#
# =====
# {"id": "mcdonalds_switzerland_457", "img": "sonicdrivein_img/mcdonalds_switzerland_457.jpg", "text": "so."}
#
# =====
# {"id": "mcdonalds_switzerland_7", "img": "sonicdrivein_img/mcdonalds_switzerland_7.jpg", "text": "we are there for you ... 🍟 🍔 especially when you 're having one of these busy days ... 🧑‍💻 🤱 🏃# youlivewedeliver@ bysofiaziani_australia0804 ## imlovinit# youlivewedeliver"}
#
# =====
# {"id": "mcdonalds_switzerland_117", "img": "sonicdrivein_img/mcdonalds_switzerland_117.jpg", "text": "the perfect match or too hot to handle? try it now in the comments or swipe to find out."}
#
# =====
# {"id": "mcdonalds_switzerland_2014", "img": "sonicdrivein_img/mcdonalds_switzerland_2014.jpg", "text": "are you missing the hour too much? maybe a delicious beverage or pastry will cheer you up;)# food# timechange# sleepy# sleepy# sleepy# foodie# picoftheday# switzerland# bestoftheday# likes# foodstagram# foodie# picoftheday# swissm"}
#
# =====
# {"id": "mcdonalds_switzerland_774", "img": "sonicdrivein_img/mcdonalds_switzerland_774.jpg", "text": "today is international kissing day and i want to tell you something through your big tasty tongue."}
#
# =====
# {"id": "mcdonalds_switzerland_45", "img": "sonicdrivein_img/mcdonalds_switzerland_45.jpg", "text": "on the way to one of our restaurants? just register with “ socialpass ” or “ mindful check-in ” and enjoy."}
#
# =====
# {"id": "mcdonalds_switzerland_2016", "img": "sonicdrivein_img/mcdonalds_switzerland_2016.jpg", "text": "you know the drill: good taste knows no age."}
#
# =====
# {"id": "mcdonalds_switzerland_1612", "img": "sonicdrivein_img/mcdonalds_switzerland_1612.jpg", "text": "we 're lovin' you 🍔🍟 even in busy times at home 😉@ friedahodel# mcdelivery# youlivewedeliver@ bysofiaziani# wedding# weddingday# mcdelivery# youlivewedeliver# youlivewedeliversof"}
#
# =====
# {"id": "mcdonalds_switzerland_1904", "img": "sonicdrivein_img/mcdonalds_switzerland_1904.jpg", "text": "we 're proud to support the stars of tomorrow and to encourage them on their way to the top."}
#
# =====
# {"id": "mcdonalds_switzerland_237", "img": "sonicdrivein_img/mcdonalds_switzerland_237.jpg", "text": "have you tried our must haves ts and deluxe? are n't they delicious?# burger# delicious# mcdonalds# mcdo# burger# deluxe# food# delicious# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo# foodie# foodie#"}
#
# =====
# {"id": "mcdonalds_switzerland_262", "img": "sonicdrivein_img/mcdonalds_switzerland_262.jpg", "text": "the mcraclette only stays available for another week."}
#
# =====
# {"id": "mcdonalds_switzerland_122", "img": "sonicdrivein_img/mcdonalds_switzerland_122.jpg", "text": "the royals are back today: discover the royal tzatziki and the mcchicken basilic."}
#
# =====
# {"id": "mcdonalds_switzerland_163", "img": "sonicdrivein_img/mcdonalds_switzerland_163.jpg", "text": "finally, it was time to fall in love again with our coca-cola™ glass 🖤."}
#
# =====
# {"id": "mcdonalds_switzerland_234", "img": "sonicdrivein_img/mcdonalds_switzerland_234.jpg", "text": "she picked up litter, she won the clean-up-day jackpot of 3'000 chf."}
#
# =====
# {"id": "mcdonalds_switzerland_50", "img": "sonicdrivein_img/mcdonalds_switzerland_50.jpg", "text": "no matter the weather- we go out in style 😎 🤠 who knows the feeling?# sundae# food# summer# mcdonalds# mcdo# tasty# summer# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie# pico"}
#
# =====
# {"id": "mcdonalds_switzerland_902", "img": "sonicdrivein_img/mcdonalds_switzerland_902.jpg", "text": "who knows that feeling of happiness? 🤩 finding leftover fries in your bag after your meal 🙌? are n't we all a little inspired by that 🍔?# smallmomentsmakeabigdifference# food# happiness# snack# foodie# picoftheday# switzerland# bestoft"}
#
# =====
# {"id": "mcdonalds_switzerland_1591", "img": "sonicdrivein_img/mcdonalds_switzerland_1591.jpg", "text": "# repost@ mcdonaldsleb ・・・ it just goes with every meal# fries# mcdonalds# lebanon# yummy# donut# food# yummy# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo# foodie# foodie"}
#
# =====
# {"id": "mcdonalds_switzerland_681", "img": "sonicdrivein_img/mcdonalds_switzerland_681.jpg", "text": "sorry… not available right now 😎.# mcdo# mcdonalds# coffee# coffee# drink# good# yummy# picoftheday# switzerland# bestoftheday# likes# igvideo# food# goodnews# picoftheday# swissmuttheday# bestofthed"}
#
# =====
# {"id": "mcdonalds_switzerland_2032", "img": "sonicdrivein_img/mcdonalds_switzerland_2032.jpg", "text": "# repost@ mcdonaldsleb ・・・ it 's not easy, but it 's fun# mcdonalds# lebanon# yummy# donut# food# art# lol# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo# food"}
#
# =====
# {"id": "mcdonalds_switzerland_732", "img": "sonicdrivein_img/mcdonalds_switzerland_732.jpg", "text": "congratulations emma and team european soccer team on reaching the round of 16 ! 🏀: today 's the match and we 're excited to hear back from you 🥰: link in bio for bio."}
#
# =====
# {"id": "mcdonalds_switzerland_904", "img": "sonicdrivein_img/mcdonalds_switzerland_904.jpg", "text": "fries with sauce on the go🍟? no problem, just right 💛# burgerfries# food# goodnews# picoftheday# switzerland# goodnewsday# swissmcdelivery# foodstagram# foodie# picoftheday# swissmcdel"}
#
# =====
# {"id": "mcdonalds_switzerland_52", "img": "sonicdrivein_img/mcdonalds_switzerland_52.jpg", "text": "in 2022, together with your help, we will reduce 200t of plastic pollution and 3d bbq restaurants will open in switzerland this summer."}
#
# =====
# {"id": "mcdonalds_switzerland_201", "img": "sonicdrivein_img/mcdonalds_switzerland_201.jpg", "text": "are you ready? ⚠️ something big is coming this summer: our first ever mcdive on the lake zürich stadelhofen."}
#
# =====
# {"id": "mcdonalds_switzerland_273", "img": "sonicdrivein_img/mcdonalds_switzerland_273.jpg", "text": "what will you choose with our summer deals? thanks to@ f."}
#
# =====
# {"id": "mcdonalds_switzerland_668", "img": "sonicdrivein_img/mcdonalds_switzerland_668.jpg", "text": "the closer it gets, the better it gets – the homestyle honey mustard veggie."}
#
# =====
# {"id": "mcdonalds_switzerland_118", "img": "sonicdrivein_img/mcdonalds_switzerland_118.jpg", "text": "you know the drill: good taste knows no age."}
#
# =====
# {"id": "mcdonalds_switzerland_864", "img": "sonicdrivein_img/mcdonalds_switzerland_864.jpg", "text": "this is not how it 's done at our# mccafe, we promise it 's nothing like it 's supposed to be."}
#
# =====
# {"id": "mcdonalds_switzerland_173", "img": "sonicdrivein_img/mcdonalds_switzerland_173.jpg", "text": "if you were wondering if the enchanting mermaids eat plankton,@ kknovaa gives you the answer: they eat filet-o-fish® . . . . . . . .# mermaids# food# enchanting# mermaids# foodie# picoftheday# switzerland"}
#
# =====
# {"id": "mcdonalds_switzerland_332", "img": "sonicdrivein_img/mcdonalds_switzerland_332.jpg", "text": "tag the lucky person that gets to share the chicken mcnuggets with you 🍔🍟 🥤."}
#
# =====
# {"id": "mcdonalds_switzerland_715", "img": "sonicdrivein_img/mcdonalds_switzerland_715.jpg", "text": "just imagine ... would you like this chocolate sauce for your chicken mcnuggets? today is a 🍫 craving day and that 's why we are reducing 200t of plastic this year, thanks to sustainable happy meal toys and our mcnuggets."}
#
# =====
# {"id": "mcdonalds_switzerland_242", "img": "sonicdrivein_img/mcdonalds_switzerland_242.jpg", "text": "wow, that 's really funny ... what 's your way to make a big mac without a big mac?# bigmacfries# burgerlover# classic# food# funny# yt# funny# foodie# mcdo# mcdonalds# refreshing# daim# toblerone# mms# mand"}
#
# =====
# {"id": "mcdonalds_switzerland_1209", "img": "sonicdrivein_img/mcdonalds_switzerland_1209.jpg", "text": "finally, it was time to fall in love again 🍔!!! from the bottom of our hearts, we wish you the best day 😉 🎁# fallforlove# mcdonalds# telenovela# sunset# love# summer# mcdo# mcdonalds# telenovela# summer#"}
#
# =====
# {"id": "mcdonalds_switzerland_1934", "img": "sonicdrivein_img/mcdonalds_switzerland_1934.jpg", "text": "we are there for you ... 🍔🍟 even in busy times at home 🏡# mcdelivery# youlivewedeliver@ bysofiaziani0804 </s># mcfamilyswitzerland# youlivewedeliver@ bysofiaziani0804 </s>#"}
#
# =====
# {"id": "mcdonalds_switzerland_1168", "img": "sonicdrivein_img/mcdonalds_switzerland_1168.jpg", "text": "even@ stevemerson shows us what ‘ s in his bag."}
#
# =====
# {"id": "mcdonalds_switzerland_1656", "img": "sonicdrivein_img/mcdonalds_switzerland_1656.jpg", "text": "congratulations emma and team mate </s> on reaching the champions league semi-finals and looking forward to seeing you soon in our livestream."}
#
# =====
# {"id": "mcdonalds_switzerland_712", "img": "sonicdrivein_img/mcdonalds_switzerland_712.jpg", "text": "keep cool and try our new iced caffè latte.( while listening to our ice cool playlist of course ➡️ link in bio). link in bio."}
#
# =====
# {"id": "mcdonalds_switzerland_682", "img": "sonicdrivein_img/mcdonalds_switzerland_682.jpg", "text": "even@ stevemerson shows us what ‘ s in his bag."}
#
# =====
# {"id": "mcdonalds_switzerland_859", "img": "sonicdrivein_img/mcdonalds_switzerland_859.jpg", "text": "if you 're team spicy chicken mcnuggets®: hurry up ... they will soon be gone."}
#
# =====
# {"id": "mcdonalds_switzerland_265", "img": "sonicdrivein_img/mcdonalds_switzerland_265.jpg", "text": "sometimes, you 're not as broke as you think you are ... especially if you use the mymcdonald 's bonus program in the app .. i do n't think so myself."}
#
# =====
# {"id": "mcdonalds_switzerland_1", "img": "sonicdrivein_img/mcdonalds_switzerland_1.jpg", "text": "here’ s how you can get the limited mcdonald’ s merch💥🔥: ➡️ all you have to do is:- get the mcdonald’ s app📱- subscribe to the loyalty program🫶🏼- collect points and exchange them for real money in"}
#
# =====
# {"id": "mcdonalds_switzerland_180", "img": "sonicdrivein_img/mcdonalds_switzerland_180.jpg", "text": "our challenge is getting harder and we 're trying to get you this time 😉 🍔 believe us, the bigger the better 😉 🤔 have you tried our bigger fries yet?# smallmomentsmakeabigdifference# mcdonalds# mcdo# friesforlife# picoftheday#"}
#
# =====
# {"id": "mcdonalds_switzerland_2001", "img": "sonicdrivein_img/mcdonalds_switzerland_2001.jpg", "text": "one big tasty, 12 variations – which one is your favorite? 🍔 😍 🤤 which one is your # 🍔 🤤? tag your favorite below in the comments."}
#
# =====
# {"id": "mcdonalds_switzerland_60", "img": "sonicdrivein_img/mcdonalds_switzerland_60.jpg", "text": "it’ s time to say thank you for donating to the ronald mcdonald house charities and therefore keeping families close in their homes."}
#
# =====
# {"id": "mcdonalds_switzerland_181", "img": "sonicdrivein_img/mcdonalds_switzerland_181.jpg", "text": "when@ malbuner bacon is so popular that they even have their own emoji."}
#
# =====
# {"id": "mcdonalds_switzerland_395", "img": "sonicdrivein_img/mcdonalds_switzerland_395.jpg", "text": "we’ ll surprise your loved ones with an extra slice of christmas 🎁."}
#
# =====
# {"id": "mcdonalds_switzerland_1037", "img": "sonicdrivein_img/mcdonalds_switzerland_1037.jpg", "text": "no matter the mean of transport, you 're always in a hurry to get there when you 're hungry."}
#
# =====
# {"id": "mcdonalds_switzerland_481", "img": "sonicdrivein_img/mcdonalds_switzerland_481.jpg", "text": "are you missing the hour too much? maybe a delicious beverage or pastry will cheer you up;)# food# timechange# sleepy# sleepy# sleepy# foodie# picoftheday# switzerland# bestoftheday# likes# foodstagram# foodie# picoftheday# swissm"}
#
# =====
# {"id": "mcdonalds_switzerland_203", "img": "sonicdrivein_img/mcdonalds_switzerland_203.jpg", "text": "the crying, fighting and worrying about who 's getting the last chicken mcnuggets has come to an end: the chicken mcnuggets® the are back."}
#
# =====
# {"id": "mcdonalds_switzerland_330", "img": "sonicdrivein_img/mcdonalds_switzerland_330.jpg", "text": "⚠️warning- crispy content ⚠️don’ t look at it too closely if you’ re hungry right now 😉 🍔# friedahodel# friedahodel# foodie# picoftheday# switzerland# bestoftheday# likes# igvideo#"}
#
# =====
# {"id": "mcdonalds_switzerland_1962", "img": "sonicdrivein_img/mcdonalds_switzerland_1962.jpg", "text": "not only can you taste our chicken big mac but you can also dream of big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac big mac"}
#
# =====
# {"id": "mcdonalds_switzerland_2020", "img": "sonicdrivein_img/mcdonalds_switzerland_2020.jpg", "text": "our# bacon clubhouse is available with beef or chicken."}
#
# =====
# {"id": "mcdonalds_switzerland_868", "img": "sonicdrivein_img/mcdonalds_switzerland_868.jpg", "text": "remember this date: 1st of march."}
#
# =====
# {"id": "mcdonalds_switzerland_256", "img": "sonicdrivein_img/mcdonalds_switzerland_256.jpg", "text": "what 's happening behind the counter? switch sides to find out."}
#
# =====
# {"id": "mcdonalds_switzerland_1948", "img": "sonicdrivein_img/mcdonalds_switzerland_1948.jpg", "text": "winter is coming and we’ re picking up: enjoy your favorite burgers summer run and enjoy the sounds of autumn in our restaurants."}
#
# =====
# {"id": "mcdonalds_switzerland_730", "img": "sonicdrivein_img/mcdonalds_switzerland_730.jpg", "text": "another difficult monday? sleep in a little longer and come have breakfast with us( we 're sure you 'll hit the slopes very soon).# mcdonalds# mcdo# breakfast# mcd# mcdonalds# breakfast# yummy# donut# foodie# picoftheday# switzerland#"}
#
# =====
# {"id": "mcdonalds_switzerland_129", "img": "sonicdrivein_img/mcdonalds_switzerland_129.jpg", "text": "today’ s the international day of# friendship."}
#
# =====
# {"id": "mcdonalds_switzerland_691", "img": "sonicdrivein_img/mcdonalds_switzerland_691.jpg", "text": "winter is coming and so is the famous chocolate triangle on top of a delicious ice cream: the mcflurry ® toblerone ® toblerone® toblerone® 🤤 ... which one will you choose?;-)# mcdonalds# mcdo# toblerone# toblerone# icecream# summer"}
#
# =====
# {"id": "mcdonalds_switzerland_232", "img": "sonicdrivein_img/mcdonalds_switzerland_232.jpg", "text": "🔥 sauce it up 🚨 this is your last chance to win one of our exclusive snipes x mcdonald’ s collab pieces."}
#
# =====
# {"id": "mcdonalds_switzerland_178", "img": "sonicdrivein_img/mcdonalds_switzerland_178.jpg", "text": "🔥 sauce it up 🚨 this is your last chance to win one of our exclusive snipes x mcdonald’ s collab pieces."}
#
# =====
# {"id": "mcdonalds_switzerland_153", "img": "sonicdrivein_img/mcdonalds_switzerland_153.jpg", "text": "🔥 sauce it up 🚨 this is your last chance to win one of our exclusive snipes x mcdonald’ s collab pieces."}
#
# =====
# {"id": "mcdonalds_switzerland_586", "img": "sonicdrivein_img/mcdonalds_switzerland_586.jpg", "text": "ready for the weekend? one more day to go and it 's a very important one: the international world egg day 🥚 🍳 start it off with a delicious egg from# mccafe# mcdonalds# mcdo# eggday# monday# cappuccino# chocolate# spring# fresh#"}
#
# =====
# {"id": "mcdonalds_switzerland_637", "img": "sonicdrivein_img/mcdonalds_switzerland_637.jpg", "text": "not sure if i 'm ready for you, but i am ready to share my best mcdonald 's moment with you 🍔🍟."}
#
# =====
# {"id": "mcdonalds_switzerland_377", "img": "sonicdrivein_img/mcdonalds_switzerland_377.jpg", "text": "what 's happening behind the counter? switch sides to find out."}
#
# =====
# {"id": "mcdonalds_switzerland_360", "img": "sonicdrivein_img/mcdonalds_switzerland_360.jpg", "text": "i 'm lovin' it."}
#
# =====
# {"id": "mcdonalds_switzerland_73", "img": "sonicdrivein_img/mcdonalds_switzerland_73.jpg", "text": "you do n't have to be a ski pro to enjoy our sundae cailler 's chocolate slopes🍦😍# sundae# chocolate# slopes# mcdonalds# mcdo# slopes# picoftheday# switzerland# bestoftheday# likes# igvideo# foodie# pico"}
#
# =====
# {"id": "mcdonalds_switzerland_2006", "img": "sonicdrivein_img/mcdonalds_switzerland_2006.jpg", "text": "our take-away bag."}
#
# =====
# {"id": "mcdonalds_switzerland_222", "img": "sonicdrivein_img/mcdonalds_switzerland_222.jpg", "text": "happy celebration tonight and see you tomorrow for the lazy 1st of january mcdelivery order 😜 🎁# lazy# mcdelivery# lazy# mcdelivery# surprise# you# lucky# first# mcdelivery# first# lucky# first# first# lucky# first# first#"}
#
# =====
# {"id": "mcdonalds_switzerland_1056", "img": "sonicdrivein_img/mcdonalds_switzerland_1056.jpg", "text": "aura +5000 if you bring the fr."}
#
# =====
# {"id": "mcdonalds_switzerland_54", "img": "sonicdrivein_img/mcdonalds_switzerland_54.jpg", "text": "there’ s a new chick on the block."}
#
# =====
# {"id": "mcdonalds_switzerland_696", "img": "sonicdrivein_img/mcdonalds_switzerland_696.jpg", "text": "we think these are pretty hot news 😎."}
#
# =====
# {"id": "mcdonalds_switzerland_1871", "img": "sonicdrivein_img/mcdonalds_switzerland_1871.jpg", "text": "photography is as simple as this reel."}
#
# =====
# {"id": "mcdonalds_switzerland_251", "img": "sonicdrivein_img/mcdonalds_switzerland_251.jpg", "text": "today, around the world, we celebrate friendship."}
#
# =====
# {"id": "mcdonalds_switzerland_706", "img": "sonicdrivein_img/mcdonalds_switzerland_706.jpg", "text": "the chicken wings are back 🍗 🥳 this week, grab the chicken wings for only 1.- and only until further notice."}
#
# =====
# {"id": "mcdonalds_switzerland_81", "img": "sonicdrivein_img/mcdonalds_switzerland_81.jpg", "text": "we are here for you ... 🍔🍟 even in busy times at home 🏡# mcdelivery# youlivewedeliver@ bysofiaziani0804 </s> </s> </s> </s> </s> </s> </s> </s> </s>"}
#
# =====
# {"id": "mcdonalds_switzerland_80", "img": "sonicdrivein_img/mcdonalds_switzerland_80.jpg", "text": "we are there for you ... 🍔🍟 even in busy times at home 🏡# mcdelivery# youlivewedeliver@ bysofiaziani_alfonso started his# bbqaroundtheworld trip from# switzerland to# sydney."}
#
# =====
# {"id": "mcdonalds_switzerland_672", "img": "sonicdrivein_img/mcdonalds_switzerland_672.jpg", "text": "⚠️ contest ⚠️ small moments make a big difference ⚠️ so make an impact today and thank you for your participation: your bffs had a great day 💙# smallmomentsmakeabigdifference# mcdonalds# mcdo# smallmomentsmakeabigdifference"}
#
# =====
# {"id": "mcdonalds_switzerland_725", "img": "sonicdrivein_img/mcdonalds_switzerland_725.jpg", "text": "⚠️ to win big, you need to be able to wear our hats."}
#
# =====
# {"id": "mcdonalds_switzerland_769", "img": "sonicdrivein_img/mcdonalds_switzerland_769.jpg", "text": "the beauty of not standing in line and waiting on your order."}
#
# =====
# {"id": "mcdonalds_switzerland_676", "img": "sonicdrivein_img/mcdonalds_switzerland_676.jpg", "text": "with the big mac, there 's never enough space left ... 🍟 😩# bigmac# mac# food# timechange# goodnews# mac# foodie# refreshing# picoftheday# switzerland# bestoftheday# likes# igvideo# foodstagram# foodie# refreshing#"}
#
# =====
# {"id": "mcdonalds_switzerland_22", "img": "sonicdrivein_img/mcdonalds_switzerland_22.jpg", "text": "it’ s international burger day, so enjoy it to the last bite."}
#
# =====
# {"id": "mcdonalds_switzerland_714", "img": "sonicdrivein_img/mcdonalds_switzerland_714.jpg", "text": "our big mac- stayin’ fabulous forever and always."}
#
# =====
# {"id": "mcdonalds_switzerland_447", "img": "sonicdrivein_img/mcdonalds_switzerland_447.jpg", "text": "the crying, fighting and worrying about who 's getting the last chicken mcnuggets has come to an end: the chicken mcnuggets® are back."}
#
# =====
# {"id": "mcdonalds_switzerland_858", "img": "sonicdrivein_img/mcdonalds_switzerland_858.jpg", "text": "it’ s time to say thank you for donating to the ronald mcdonald house charities and therefore keeping families close in their hearts."}
#
# =====
# {"id": "mcdonalds_switzerland_746", "img": "sonicdrivein_img/mcdonalds_switzerland_746.jpg", "text": "one big tasty, 12 variations – which one is your favorite? 🍔 😍 🤤 which one is your favorite? 🤤 thanks to@ sh."}
#
# =====
# {"id": "mcdonalds_switzerland_2026", "img": "sonicdrivein_img/mcdonalds_switzerland_2026.jpg", "text": "craving for fries? comment 🤏 to try to get one of these 🍟 🍔 📚."}
#
# =====
# Load 155 data from split(s).

# %%
# !python ./hm_inf.py --seed 42 --model U --test clip_100up_only200_passlength_12_MC_base_oxford_800_8_300_82_generate2_1 --imgdir hm_vgattr3636_MC --batchSize 1 --tr bert-large-cased --tsv --num_features 36 --num_pos 6 --exp U36 --loadfin ./input/LASTtrain.pth
# Out:
# UNEXPECTED:  []
# MISSING:  ['bert.img_embeddings.img_linear.weight', 'bert.img_embeddings.img_linear.bias', 'bert.img_embeddings.img_layer_norm.weight', 'bert.img_embeddings.img_layer_norm.bias', 'bert.img_embeddings.pos_layer_norm.weight', 'bert.img_embeddings.pos_layer_norm.bias', 'bert.img_embeddings.pos_linear.weight', 'bert.img_embeddings.pos_linear.bias', 'bert.img_embeddings.LayerNorm.weight', 'bert.img_embeddings.LayerNorm.bias']
# ERRORS:  []
# REINITING:  Linear(in_features=1024, out_features=2048, bias=True)
# REINITING:  GeLU()
# REINITING:  LayerNorm((2048,), eps=1e-12, elementwise_affine=True)
# REINITING:  Linear(in_features=2048, out_features=2, bias=True)
# REINITING:  Sequential(
#   (0): Linear(in_features=1024, out_features=2048, bias=True)
#   (1): GeLU()
#   (2): LayerNorm((2048,), eps=1e-12, elementwise_affine=True)
#   (3): Linear(in_features=2048, out_features=2, bias=True)
# )
# Load model from ./input/LASTtrain.pth
# Load 155 data from split(s) clip_100up_only200_passlength_12_MC_base_oxford_800_8_300_82_generate2_1.
# Start to load Faster-RCNN detected objects from data/hm_vgattr3636_MC.tsv
# Loaded 155 images in file data/hm_vgattr3636_MC.tsv in 0 seconds.
# Use 155 data in torch dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      155 non-null    object
#  1   proba   155 non-null    float32
#  2   label   155 non-null    int64
# dtypes: float32(1), int64(1), object(1)
# memory usage: 3.2+ KB
# None
# Some weights of BertU were not initialized from the model checkpoint at bert-large-cased and are newly initialized: ['bert.img_embeddings.img_linear.weight', 'bert.img_embeddings.img_linear.bias', 'bert.img_embeddings.img_layer_norm.weight', 'bert.img_embeddings.img_layer_norm.bias', 'bert.img_embeddings.pos_layer_norm.weight', 'bert.img_embeddings.pos_layer_norm.bias', 'bert.img_embeddings.pos_linear.weight', 'bert.img_embeddings.pos_linear.bias', 'bert.img_embeddings.LayerNorm.weight', 'bert.img_embeddings.LayerNorm.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !cat ../vilio/data/U36_example.csv
# Out:
# id,proba,label
# 10002,-9.773689270019531,0
